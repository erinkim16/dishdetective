# %% [markdown]
# <a href="https://colab.research.google.com/github/erinkim16/dishdetective/blob/main/erin_finals_merged.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install word2number

import pandas as pd
import re
from word2number import w2n
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting word2number
#   Downloading word2number-1.1.zip (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: word2number
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5568 sha256=8a0accce3dd70440e8917987c8fdb116105c930e134de81c5c5b89ce312ed29b
#   Stored in directory: /root/.cache/pip/wheels/cd/ef/ae/073b491b14d25e2efafcffca9e16b2ee6d114ec5c643ba4f06
# Successfully built word2number
# Installing collected packages: word2number
# Successfully installed word2number-1.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv('/content/drive/MyDrive/311/cleaned_data_combined_modified.csv')

# Display the first few rows of the DataFrame
df.head()
# Out:
#        id  \
# 0  716549
# 1  715742
# 2  727333
# 3  606874
# 4  505318
#
#    Q1: From a scale 1 to 5, how complex is it to make this food? (Where 1 is the most simple, and 5 is the most complex)  \
# 0                                                  3
# 1                                                  4
# 2                                                  3
# 3                                                  4
# 4                                                  2
#
#   Q2: How many ingredients would you expect this food item to contain?  \
# 0                                                  6
# 1                                        bread, meet
# 2                                                  5
# 3                                                6-7
# 4                                          3 or more
#
#   Q3: In what setting would you expect this food to be served? Please check all that apply  \
# 0         Week day lunch,At a party,Late night snack
# 1         Week day lunch,At a party,Late night snack
# 2  Week day lunch,Week day dinner,Weekend lunch,W...
# 3  Week day lunch,Week day dinner,Weekend lunch,W...
# 4  Week day lunch,Week day dinner,Weekend lunch,W...
#
#   Q4: How much would you expect to pay for one serving of this food item?  \
# 0                                                  5
# 1                               5$ for a large piece
# 2                                           10dollar
# 3                                                $3
# 4                                                $5
#
#   Q5: What movie do you think of when thinking of this food item?  \
# 0                  Cloudy with a Chance of Meatballs
# 1              All sort of american young boy movies
# 2                                       action movie
# 3                                          Mamma Mia
# 4                  Cloudy with a chance of meatballs
#
#   Q6: What drink would you pair with this food item?  \
# 0                                              Coke
# 1                                               Coke
# 2                                               cola
# 3                                               Soda
# 4                                               Soda
#
#   Q7: When you think about this food item, who does it remind you of?  \
# 0                                            Friends
# 1                         Friends,Teachers,Strangers
# 2                                            Friends
# 3                          Siblings,Friends,Teachers
# 4                                   Siblings,Friends
#
#   Q8: How much hot sauce would you add to this food item?  Label
# 0                                    A little (mild)       Pizza
# 1                                                NaN       Pizza
# 2                         A moderate amount (medium)       Pizza
# 3  I will have some of this food item with my hot...       Pizza
# 4                                    A little (mild)       Pizza

# %% [markdown]
# How to parse "How many ingredients" Q2
#
# *  take average
# *  take first number
# * take last number
# * count how many spaces in between the words or commas

# %%
# Define a dictionary to map month abbreviations to numbers
month_map = {
    'Jan': '1',
    'Feb': '2',
    'Mar': '3',
    'Apr': '4',
    'May': '5',
    'Jun': '6',
    'Jul': '7',
    'Aug': '8',
    'Sep': '9',
    'Oct': '10',
    'Nov': '11',
    'Dec': '12'
}

# Function to convert date format
def convert_date_format(date_str):
    if isinstance(date_str, str) and '-' in date_str:
        try:
            day, month_abbr = date_str.split('-')
            month_num = month_map.get(month_abbr, month_abbr)
            return f"{int(month_num)}-{int(day)}"
        except ValueError:
           return date_str
    return date_str

# Apply the function to the Q2 column
df['Q2: How many ingredients would you expect this food item to contain?'] = df['Q2: How many ingredients would you expect this food item to contain?'].apply(convert_date_format)

# Function to take the average if there's a range(either with '-' or 'to')
def average_of_range(text):
  if isinstance(text, str):
    range_match = re.search(r'(\d+)[\s-]+(\d+)', text)
    range_match2 = re.search(r'(\d+)\s* to \s*(\d+)', text)

    if range_match is not None:
      num1, num2 = int(range_match.group(1)), int(range_match.group(2))
      return int((num1 + num2) / 2 )# Take the average of the range
    elif range_match2 is not None:
      num1, num2 = int(range_match2.group(1)), int(range_match2.group(2))
      return int((num1 + num2) / 2)
    else:
      return text

# Apply the function to the Q2 column
df['Q2: How many ingredients would you expect this food item to contain?'] = df['Q2: How many ingredients would you expect this food item to contain?'].apply(average_of_range)


# Function to extract numerical values in data entry
def extract_number(text):
  # check if entry is string
  if isinstance(text, str):
    # search for any digits in the text
    # note, this is called after all previous functions, which should indicate high likelihood
    # that what's left is the answer value with only v/ small margin of error
    num = re.search(r'(\d+)', text)

    # if found, return as int
    if num is not None:
      return int(num.group(1))

    # if no match, return original entry
    else:
      return text
  # if not, return original entry
  else:
    return text

# Apply the function to the Q2 column
df['Q2: How many ingredients would you expect this food item to contain?'] = df['Q2: How many ingredients would you expect this food item to contain?'].apply(extract_number)


def convert_wrds(text):
    if isinstance(text, str):
        # Regex to find hyphenated numbers (e.g., "twenty-two", "one-hundred-three")
        hyphenated_pattern = r'\b(?:one|two|three|four|five|six|seven|eight|nine|ten|eleven|twelve|thirteen|fourteen|fifteen|sixteen|seventeen|eighteen|nineteen|twenty|thirty|forty|fifty|sixty|seventy|eighty|ninety|hundred|thousand|million|billion)(?:-\s?(?:one|two|three|four|five|six|seven|eight|nine|ten|eleven|twelve|thirteen|fourteen|fifteen|sixteen|seventeen|eighteen|nineteen|twenty|thirty|forty|fifty|sixty|seventy|eighty|ninety|hundred|thousand|million|billion))+\b'

        # Regex to find single (non-hyphenated) number words
        single_pattern = r'\b(one|two|three|four|five|six|seven|eight|nine|ten|eleven|twelve|thirteen|fourteen|fifteen|sixteen|seventeen|eighteen|nineteen|twenty|thirty|forty|fifty|sixty|seventy|eighty|ninety|hundred|thousand|million|billion)\b'

        # Look for a hyphenated number first
        hyphenated_match = re.search(hyphenated_pattern, text, re.IGNORECASE)
        if hyphenated_match:
            try:
                return w2n.word_to_num(hyphenated_match.group(0))  # Convert full hyphenated number
            except ValueError:
                return hyphenated_match.group(0)  # Return as text if conversion fails

        # If no hyphenated number, look for a single non-hyphenated number
        single_match = re.search(single_pattern, text, re.IGNORECASE)
        if single_match:
            try:
                return w2n.word_to_num(single_match.group(1))  # Convert first non-hyphenated number
            except ValueError:
                return single_match.group(1)  # Return as text if conversion fails

    return text  # Return original text if no numbers found

# Apply function to the Q2 column
df['Q2: How many ingredients would you expect this food item to contain?'] = df[
    'Q2: How many ingredients would you expect this food item to contain?'
].apply(convert_wrds)

# Function to count the number of ingredients if responses are comma-separated or use '*'
def count_ingredients(text):
    if isinstance(text, str):  # Ensure it's a string
        if ',' in text:  # Count comma-separated items
            return len([item.strip() for item in text.split(',') if item.strip()])
        elif '* ' in text:  # Count bullet-pointed items
            return len([item.strip() for item in text.split('* ') if item.strip()])
    return text  # If it's a single ingredient or doesn't match conditions, return 1

# Apply the function to the Q2 column
df['Q2: How many ingredients would you expect this food item to contain?'] = df[
    'Q2: How many ingredients would you expect this food item to contain?'
].apply(count_ingredients)


# Function to identify likely 'outliers' (ie. stories/anecdotes, 'i don't knows', etc.)
def outlier_rest(text):
  # check if entry is string
  if isinstance(text, str):
    # search for any text characters
    is_match = re.search(r'(\s+)', text)
    # if found, return 'None' as a string to identify an outlier in the data
    if is_match is not None:
      return 'None'

    # if not, return original entry
    else:
      return text
  # if not, return original
  else:
    return text

df['Q2: How many ingredients would you expect this food item to contain?'] = df[
    'Q2: How many ingredients would you expect this food item to contain?'
].apply(outlier_rest)

# %% [markdown]
# How to parse "How much would you pay" Q4
# *   first number seen
# *   average of many numbers

# %%
# Function to take the average if there's a range(either with '-' or 'to')
def q4_range(text):
  # make sure data entry is a string
  if isinstance(text, str):

    # case where there's a range and no dollar sign (eg. 2-5)
    no_sign = re.search(r'(\d+)\s*(?:-|to|up to)\s*(\d+)', text)

    # case where there's a range w/ a dollar sign at the front (eg. 5)
    sign_front = re.search(r'(\d+)\s*(?:-|to|up to)\s*$(\d+)', text)

    # case where there's a range w/ a dollar sign at the back (eg. 2)
    sign_back = re.search(r'(\d+)$\s*(?:-|to|up to)\s*(\d+)', text)

    # if one is not None, ie a match was found, extract #s and take average
    if no_sign is not None:
      num1, num2 = int(no_sign.group(1)), int(no_sign.group(2))
      return (num1 + num2) / 2

    elif sign_front is not None:
      num1, num2 = int(sign_front.group(1)), int(sign_front.group(2))
      return (num1 + num2) / 2

    elif sign_back is not None:
      num1, num2 = int(sign_back.group(1)), int(sign_back.group(2))
      return (num1 + num2) / 2

    # if no match found, return original data entry
    else:
      return text
  # if not string, return original entry
  else:
    return text

# Function to find float money values and return as floats
def floats(text):
  # check if data entry is a string
  if isinstance(text, str):
    # find values in full 'monetary' form(ie. 12.00 instead of 12, or 12.99)
    float_vars = re.search(r'(\d+\.\d{2})', text)

    # if not None, ie match found, return the value in float format
    if float_vars is not None:
      return float(float_vars.group(1))

    # if no match found, return original entry
    else:
      return text
  # if not string, return original entry
  else:
    return text

# Function to find values with written 'money' indications (ie. 12 dollars)
def dollars(text):
  # check if entry is a string
  if isinstance(text, str):
    # search for variations of 'money-indicative' words that have a number directly preceeding it
    dollar_vars = re.search(r'(\d+)\s*(dollars|dollar|dollor|bucks|buck)', text, re.IGNORECASE)
    currencies = re.search(r'(\d+)\s*(CAD|USD|Canadian)', text, re.IGNORECASE)

    # if match for either found, return float value of that number
    if dollar_vars is not None:
      return float(dollar_vars.group(1))
    elif currencies is not None:
      return float(currencies.group(1))

    # if no match found, return original
    else:
      return text
  # if not, return original entry
  else:
    return text

# Function to find values directly preceding or following a '$' symbol
def dollar_sign(text):
  # make sure entry is a string
  if isinstance(text, str):

    # search for numbers either before or after '$'
    # note, this is called after q4_range to not misselect 5 as just 4
    sign_first = re.search(r'$(\d+)', text)
    sign_after = re.search(r'(\d+)\s*$', text)

    # if found, return value as float
    if sign_first is not None:
      return float(sign_first.group(1))
    elif sign_after is not None:
      return float(sign_after.group(1))

    # if no match found, return original entry
    else:
      return text
  # if not, return original entry
  else:
    return text

# Function to extract numerical values in data entry
def extract_number(text):
  # check if entry is string
  if isinstance(text, str):
    # search for any digits in the text
    # note, this is called after all previous functions, which should indicate high likelihood
    # that what's left is the answer value with only v/ small margin of error
    num = re.search(r'(\d+)', text)

    # if found, return as float
    if num is not None:
      return float(num.group(1))

    # if no match, return original entry
    else:
      return text
  # if not, return original entry
  else:
    return text

# Function to find written numbercal values and convert into proper form

def convert_wrds(text):
    if isinstance(text, str):
        # Regex to find hyphenated numbers (e.g., "twenty-two", "one-hundred-three")
        hyphenated_pattern = r'\b(?:one|two|three|four|five|six|seven|eight|nine|ten|eleven|twelve|thirteen|fourteen|fifteen|sixteen|seventeen|eighteen|nineteen|twenty|thirty|forty|fifty|sixty|seventy|eighty|ninety|hundred|thousand|million|billion)(?:-\s?(?:one|two|three|four|five|six|seven|eight|nine|ten|eleven|twelve|thirteen|fourteen|fifteen|sixteen|seventeen|eighteen|nineteen|twenty|thirty|forty|fifty|sixty|seventy|eighty|ninety|hundred|thousand|million|billion))+\b'

        # Regex to find single (non-hyphenated) number words
        single_pattern = r'\b(one|two|three|four|five|six|seven|eight|nine|ten|eleven|twelve|thirteen|fourteen|fifteen|sixteen|seventeen|eighteen|nineteen|twenty|thirty|forty|fifty|sixty|seventy|eighty|ninety|hundred|thousand|million|billion)\b'

        # Look for a hyphenated number first
        hyphenated_match = re.search(hyphenated_pattern, text, re.IGNORECASE)
        if hyphenated_match:
            try:
                return w2n.word_to_num(hyphenated_match.group(0))  # Convert full hyphenated number
            except ValueError:
                return hyphenated_match.group(0)  # Return as text if conversion fails

        # If no hyphenated number, look for a single non-hyphenated number
        single_match = re.search(single_pattern, text, re.IGNORECASE)
        if single_match:
            try:
                return w2n.word_to_num(single_match.group(1))  # Convert first non-hyphenated number
            except ValueError:
                return single_match.group(1)  # Return as text if conversion fails

    return text  # Return original text if no numbers found

# Apply function to the Q2 column
df['Q2: How many ingredients would you expect this food item to contain?'] = df[
    'Q2: How many ingredients would you expect this food item to contain?'
].apply(convert_wrds)

# Function to identify likely 'outliers' (ie. stories/anecdotes, 'i don't knows', etc.)
def outlier_rest(text):
  # check if entry is string
  if isinstance(text, str):
    # search for any text characters
    is_match = re.search(r'(\s+)', text)
    # if found, return 'None' as a string to identify an outlier in the data
    if is_match is not None:
      return 'None'

    # if not, return original entry
    else:
      return text
  # if not, return original
  else:
    return text

# Applying all functions to the Q4 column
# Important note! ORDER MATTERS! Specific order to identify cases, and not *mis*-identify cases with only very small margin of error

# Apply the date function to the Q4 column
df['Q4: How much would you expect to pay for one serving of this food item?'] = df['Q4: How much would you expect to pay for one serving of this food item?'].apply(convert_date_format)

# Apply the q4_range function to the Q4 column
df['Q4: How much would you expect to pay for one serving of this food item?'] = df['Q4: How much would you expect to pay for one serving of this food item?'].apply(q4_range)

# Apply the floats function to the Q4 column
df['Q4: How much would you expect to pay for one serving of this food item?'] = df['Q4: How much would you expect to pay for one serving of this food item?'].apply(floats)

# Apply the dollars function to the Q4 column
df['Q4: How much would you expect to pay for one serving of this food item?'] = df['Q4: How much would you expect to pay for one serving of this food item?'].apply(dollars)

# Apply the dollar_sign function to the Q4 column
df['Q4: How much would you expect to pay for one serving of this food item?'] = df['Q4: How much would you expect to pay for one serving of this food item?'].apply(dollar_sign)

# Apply the extract number function to the Q4 column
df['Q4: How much would you expect to pay for one serving of this food item?'] = df['Q4: How much would you expect to pay for one serving of this food item?'].apply(extract_number)

# Apply the convert words function to the Q4 column
df['Q4: How much would you expect to pay for one serving of this food item?'] = df['Q4: How much would you expect to pay for one serving of this food item?'].apply(convert_wrds)

# Apply the outlier_rest function to the Q4 column
df['Q4: How much would you expect to pay for one serving of this food item?'] = df['Q4: How much would you expect to pay for one serving of this food item?'].apply(outlier_rest)

df.to_csv('\content\test.csv', index=False)

# %% [markdown]
# Q6: can parse the data by classifying similar ones, like coke, soda, sprite, wine, ...
#
#
# *   by whcihever one we find first from sort data set alphabetically
# * find all matches from data set and randomly choose it
# * find all matches from data set and pick which one comes earliest (first)
# *   by whichever one we find first from sort data set by frequency of dataset.

# %%
# pandas, numpy, download stuff

######### drinks ############

# lowercase everything

# find the median word length to decide how to make split
# of yap vs actual movie name / drink name

# ex: only 2 words length is enough to describe most drinks, only use that as
# "data set " comparaison

# group together based on persoal thought n how generalizable it is
# using a dataset , soda~softdrink~pop same,

# sort "data set" popularity (counts)

# for long answers for drinks, to match with the "data set"
# and take first match

# keep track of any data that couldn't be matched
# will see if we can label it as 'None' / noise
# or if we need to include more drinks in our 'dataset'

# pandas, numpy, download stuff

######## movie #############

# remove everyting after :......
# if there's a number , like shrek 2, remove the number 2, but if its 16 candles,
# don't remove cos its likely part of the title

# lowercase thing

# divide based on median, so we divide the yapping rants vs actual titles (assuming its likely chances)

# research to try and find data set with all movies ever

# For those that couldn't find a movie and was too big, first try to find the first actual movie name
# that shows up, otherwise label it as 'None'

# %% [markdown]
# Q5 Movie

# %%
# pandas, numpy, download stuff

######### drinks ############

# lowercase everything

# find the median word length to decide how to make split
# of yap vs actual movie name / drink name

# ex: only 2 words length is enough to describe most drinks, only use that as
# "data set " comparaison

# group together based on persoal thought n how generalizable it is
# using a dataset , soda~softdrink~pop same,

# sort "data set" popularity (counts)

# for long answers for drinks, to match with the "data set"
# and take first match

# keep track of any data that couldn't be matched
# will see if we can label it as 'None' / noise
# or if we need to include more drinks in our 'dataset'

######## movie #############

# %% [markdown]
# Q5 Movie

# %%
""" now look at cluster and fine tune trainign set """


""" game plan:
group up (none): cluser id  254, 4 255	258 277 84 307 44   216 327 150  304 20
sort each group by length, then the final label is the median one in the lsit



get a list of all the labels and thier group id, do classification with the logner sentences
parsing the longer sentences:
get rid of common stop words, use the outlier words if it's in it to consider it None, if it matches with none from our list even after parsing mkae it a
new category, now go thru entire new longer sentence df nad see if any are similar enough to merge

last, merge back using the original id's
"""


"""
### for bigger sentencees


# Define outlier phrases
outlier_phrases = [
    "come to mind",
    "think of", "nothing comes", "comes to", "to mind", "come to",
    "i dont", "none i",
    "i think", "think of", "none", "not sure", "unsure", "None",
    "idk", "nothing", "not ", "any movie", "even though"
]

# Function to check if a response is an outlier
def is_outlier(response):
    # Check if the response is fully blank or empty
    if not response.strip():  # Removes whitespace and checks if empty
        return True
    response_lower = response.lower()  # Case-insensitive matching
    for phrase in outlier_phrases:
        if phrase in response_lower:
            return True
    return False

# Separate outliers and "no" responses
outliers = []
no_responses = []
updated_clusters = {}

for cluster_id, group in clusters.items():
    updated_group = []
    for response in group:
        if response.strip().lower() == "no":  # Check if response is exactly "no"
            no_responses.append(response)  # Add to "no" responses
        elif is_outlier(response):
            outliers.append(response)  # Add to general outliers
        else:
            updated_group.append(response)  # Keep in the original cluster
    if updated_group:  # Only add non-empty clusters
        updated_clusters[cluster_id] = updated_group

# Add the "no" responses and outliers as separate clusters
if no_responses or outliers:
    updated_clusters['outliers'] = no_responses + outliers

# Convert updated clusters into a DataFrame
cluster_data = []
for cluster_id, group in updated_clusters.items():
    cluster_data.append({
        'Cluster ID': cluster_id,
        'Responses': ', '.join(group),  # Combine responses into a single string
        'Number of Responses': len(group)  # Add count of responses in the cluster
    })

# Create the DataFrame
clusters_df = pd.DataFrame(cluster_data)

clusters_df = clusters_df.sort_values(by='Number of Responses', ascending=False)

# Save the DataFrame to a CSV file
clusters_df.to_csv('/content/clusters_output_v2.csv', index=False)

# Output the DataFrame
print(clusters_df)
"""
# Out:
# '\n### for bigger sentencees\n\n\n# Define outlier phrases\noutlier_phrases = [\n    "come to mind",\n    "think of", "nothing comes", "comes to", "to mind", "come to",\n    "i dont", "none i",\n    "i think", "think of", "none", "not sure", "unsure", "None",\n    "idk", "nothing", "not ", "any movie", "even though"\n]\n\n# Function to check if a response is an outlier\ndef is_outlier(response):\n    # Check if the response is fully blank or empty\n    if not response.strip():  # Removes whitespace and checks if empty\n        return True\n    response_lower = response.lower()  # Case-insensitive matching\n    for phrase in outlier_phrases:\n        if phrase in response_lower:\n            return True\n    return False\n\n# Separate outliers and "no" responses\noutliers = []\nno_responses = []\nupdated_clusters = {}\n\nfor cluster_id, group in clusters.items():\n    updated_group = []\n    for response in group:\n        if response.strip().lower() == "no":  # Check if response is exactly "no"\n            no_responses.append(response)  # Add to "no" responses\n        elif is_outlier(response):\n            outliers.append(response)  # Add to general outliers\n        else:\n            updated_group.append(response)  # Keep in the original cluster\n    if updated_group:  # Only add non-empty clusters\n        updated_clusters[cluster_id] = updated_group\n\n# Add the "no" responses and outliers as separate clusters\nif no_responses or outliers:\n    updated_clusters[\'outliers\'] = no_responses + outliers\n\n# Convert updated clusters into a DataFrame\ncluster_data = []\nfor cluster_id, group in updated_clusters.items():\n    cluster_data.append({\n        \'Cluster ID\': cluster_id,\n        \'Responses\': \', \'.join(group),  # Combine responses into a single string\n        \'Number of Responses\': len(group)  # Add count of responses in the cluster\n    })\n\n# Create the DataFrame\nclusters_df = pd.DataFrame(cluster_data)\n\nclusters_df = clusters_df.sort_values(by=\'Number of Responses\', ascending=False)\n\n# Save the DataFrame to a CSV file\nclusters_df.to_csv(\'/content/clusters_output_v2.csv\', index=False)\n\n# Output the DataFrame\nprint(clusters_df)\n'

# %%
#### cleaning Q6: What drink would you pair with this food item? ####
# NOTES
# make everything lowercase
# find median length of entry = divide into small entries and large entries
    # PROBLEM: median of drinks = 4 --> but this feels a little large
    # allows for entries like 'Green tea or water' to count as a single label

# small entries (like 2 words) will be part of data set
# large entries -- search through for first appearing label from small entries data set

####
# bag of words to make own dataset
# yap sessions -- take the label that appears first (this is likely their instinct)
# if negated words (no, not, dont) = 'None'
  # maybe just all the hard to classify ones
  # put all the hard to classify words into separate set -- analyze later

# %%
# !pip install pandas
import pandas as pd
import numpy as np
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv('\content\test.csv')
# Display the first few rows of the DataFrame
df.head()
# Out:
#        id  \
# 0  716549
# 1  715742
# 2  727333
# 3  606874
# 4  505318
#
#    Q1: From a scale 1 to 5, how complex is it to make this food? (Where 1 is the most simple, and 5 is the most complex)  \
# 0                                                  3
# 1                                                  4
# 2                                                  3
# 3                                                  4
# 4                                                  2
#
#   Q2: How many ingredients would you expect this food item to contain?  \
# 0                                                  6
# 1                                                  2
# 2                                                  5
# 3                                                  6
# 4                                                  3
#
#   Q3: In what setting would you expect this food to be served? Please check all that apply  \
# 0         Week day lunch,At a party,Late night snack
# 1         Week day lunch,At a party,Late night snack
# 2  Week day lunch,Week day dinner,Weekend lunch,W...
# 3  Week day lunch,Week day dinner,Weekend lunch,W...
# 4  Week day lunch,Week day dinner,Weekend lunch,W...
#
#    Q4: How much would you expect to pay for one serving of this food item?  \
# 0                                                5.0
# 1                                                5.0
# 2                                               10.0
# 3                                                3.0
# 4                                                5.0
#
#   Q5: What movie do you think of when thinking of this food item?  \
# 0                  Cloudy with a Chance of Meatballs
# 1              All sort of american young boy movies
# 2                                       action movie
# 3                                          Mamma Mia
# 4                  Cloudy with a chance of meatballs
#
#   Q6: What drink would you pair with this food item?  \
# 0                                              Coke
# 1                                               Coke
# 2                                               cola
# 3                                               Soda
# 4                                               Soda
#
#   Q7: When you think about this food item, who does it remind you of?  \
# 0                                            Friends
# 1                         Friends,Teachers,Strangers
# 2                                            Friends
# 3                          Siblings,Friends,Teachers
# 4                                   Siblings,Friends
#
#   Q8: How much hot sauce would you add to this food item?  Label
# 0                                    A little (mild)       Pizza
# 1                                                NaN       Pizza
# 2                         A moderate amount (medium)       Pizza
# 3  I will have some of this food item with my hot...       Pizza
# 4                                    A little (mild)       Pizza

# %%
#### isolate the column with the data relating to drinks (Q6)
q6 = df[['Q6: What drink would you pair with this food item?']] # q6 is a dataframe
q6 = q6.rename(columns={'Q6: What drink would you pair with this food item?': 'drinks'})  # making it easier to reference this column
q6['drinks'] = q6['drinks'].str.lower() # q6 is one column = Pandas Series, also lowercasing all entries
# print(q6['drinks'])

#### divide based on median, so we divide the yapping rants vs actual titles (assuming its likely chances)
word_lengths = q6['drinks'].str.split().explode().str.len()   # this is a series (same order as q6['drinks']) of num words in each entry
print(word_lengths)
# Compute the median word length across the entire column
median_word_length = word_lengths.median()  # this is a float
print('median = ', median_word_length)
######### PROBLEMS

# med_len(q6, 'drinks')
# Out:
# 0        4.0
# 1        4.0
# 2        4.0
# 3        4.0
# 4        4.0
#         ...
# 1643     3.0
# 1643     6.0
# 1643     4.0
# 1643     3.0
# 1643    10.0
# Name: drinks, Length: 3274, dtype: float64
# median =  4.0

# %%
#### define a function to isolate a set of entries that are greater than 2
def divide_into_short_long(df, col):
  df = df.copy()
  df['num_words'] = df[col].str.split().str.len()  # counting number words in each entry
  df['original_index'] = df.index  # Store the original index

  small_entries_df = df[df['num_words'] <= 2].drop(columns=['num_words'])
  large_entries_df = df[df['num_words'] > 2].drop(columns=['num_words'])
  return small_entries_df, large_entries_df

# %%
#### isolate short words and long words
import statistics

small_entries, large_entries = divide_into_short_long(q6, 'drinks')

#### for testing
# print("small entries= \n")
# print(small_entries)
# print("\n")
print("large entries= \n")
large_entries.head()
# print(statistics.median([len(entry) for entry in small_entries]))   # high key idk why I needed this function
# Out:
# large entries=
#                                                drinks  original_index
# 15                                     pop like coke               15
# 24                      soft drinks. for example, 7up              24
# 32                             coca-cola and iced tea              32
# 35  all sorts of carbonated drinks(e.g. coca-cola,...              35
# 57                              carbonated soft drink              57

# %%
# !pip install thefuzz
from thefuzz import fuzz, process
import re
# Out:
# Collecting thefuzz
#   Downloading thefuzz-0.22.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from thefuzz)
#   Downloading rapidfuzz-3.12.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Downloading thefuzz-0.22.1-py3-none-any.whl (8.2 kB)
# Downloading rapidfuzz-3.12.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 20.6 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, thefuzz
# Successfully installed rapidfuzz-3.12.2 thefuzz-0.22.1

# %%
from sys import set_coroutine_origin_tracking_depth
"""
Now let's start classifying based on the data set:
"""
import jellyfish
from scipy.sparse.csgraph import connected_components
from scipy.spatial.distance import squareform
import re
## Notes
# jellyfish - providing Jaro-Winkler similarity
# scipy.sparse.csgraph - for dinsing clusters in similarity graph
# re - (regex) for cleaning data

def clean_text(text):
    # Remove non-alphanumeric characters except spaces
    cleaned = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    # Normalize spaces (replace multiple spaces with a single space)
    cleaned = re.sub(r'\s+', ' ', cleaned).strip()
    return cleaned

# Example data: list of drink responses
responses = small_entries[['drinks', 'original_index']].copy()
responses['drinks'] = responses['drinks'].astype(str).apply(clean_text)  # Apply the cleaning function to the entire column
response_list = responses['drinks'].to_numpy()    # converting to numpy array (bc that's what clean_text takes)

# Function to compute the similarity matrix -- ie preparing to use jaro winkler similarity test
def compute_similarity_matrix(responses, similarity_func, threshold):
    n = len(responses)
    similarity_matrix = np.zeros((n, n))

    for i in range(n):
        for j in range(i + 1, n):
            similarity = similarity_func(responses[i], responses[j])
            if similarity >= threshold:
                similarity_matrix[i, j] = 1
                similarity_matrix[j, i] = 1

    return similarity_matrix

# see how similar the entries are using Jaro-Winkler similarity
threshold = 0.90 # even if do 0.8 it puts miso soup and sake together -- this is why we apply fuzzy matching afterwards
similarity_matrix = compute_similarity_matrix(response_list, jellyfish.jaro_winkler_similarity, threshold)

# Identify clusters
n_components, labels = connected_components(csgraph=similarity_matrix, directed=False)

# Group words & indices into clusters
clusters = {}  # dictionary mapping the group number to the group
for i, label in enumerate(labels):
    clusters.setdefault(label, []).append((response_list[i], responses['original_index'].iloc[i]))

## new stuff for bettering matches -- applying fuzzy match across clusters
refined_clusters = {}
for cluster_id, group in clusters.items():
    for word, index in group:
        if refined_clusters:
            # comparing across all clusters -- not just within one
            match, score = process.extractOne(word, list(refined_clusters.keys()), scorer=fuzz.partial_ratio)
            if match and score >= 85: # fuzzy matching threshold -- different from jaro-winkler
                refined_clusters[match].append((word, index))
            else:
                # case for when item is the first element in refined_cluster
                refined_clusters[word] = [(word, index)]
        else:
            # case for when item is not the first element in refined_cluster
            refined_clusters[word] = [(word, index)]

# ## manually combining some clusters (ex. coke and cola) -- previous location of code block (see end of doc now)

# Convert refined clusters to DataFrame
cluster_data = []
for cluster_id, words_indices in refined_clusters.items():
    words = [word for word, idx in words_indices]
    indices = [idx for word, idx in words_indices]
    count = len(words)

    cluster_data.append([cluster_id, count, ", ".join(words), indices])

cluster_df = pd.DataFrame(cluster_data, columns=['Cluster Id', 'Count', 'Cluster Words', 'Indices'])
cluster_df = cluster_df.sort_values(by='Count', ascending=False).reset_index(drop=True) #  use sort_values to reorder the clusters by count
cluster_df["Indices"] = cluster_df["Indices"].apply(lambda x: [int(i) for i in x])  # convert np.uint64 to int -- otherwise is weird in csv file
cluster_df.to_csv('/content/clusters1.csv', index=False) # save to csv

# Print results
# print(cluster_df)

# %%
#### create a list of tuples: a label and its frequency
label_freqs = []
for cluster_id, group in refined_clusters.items():
  # print(group, "\n\n")  # for testing
  freq = len(group)
  if len(label_freqs) == 0:
    label_freqs.append((cluster_id, freq))
  else:
    # compare to see where (based on frequency) this label lands in the list
    inserted = False
    for i in range(len(label_freqs)):
      if freq > label_freqs[i][1]:
        label_freqs.insert(i, (cluster_id, freq))
        inserted = True
        break
    if not inserted:
      label_freqs.append((cluster_id, freq))
print(label_freqs)
# Out:
# [('lemon water', 321), ('coke', 281), ('ice tea', 111), ('soda', 110), ('cola', 99), ('juice', 62), ('sprite', 50), ('diet pepsi', 45), ('water sake', 41), ('green tea', 35), ('soup', 30), ('pop', 23), ('nestea', 22), ('soft drink', 21), ('root beer', 19), ('ginger ale', 17), ('milk', 12), ('lemonade', 11), ('red wine', 11), ('orange fanta', 10), ('ayran', 10), ('matcha', 7), ('sparkling water', 6), ('hot tea', 6), ('barley tea', 6), ('bubble tea', 4), ('oolong tea', 4), ('barbican', 4), ('hot water', 3), ('lassi', 3), ('calpis', 3), ('lemon tea', 2), ('mountain dew', 2), ('dr pepper', 2), ('carbonated drink', 2), ('crush', 2), ('7up', 2), ('pineapple fanta', 2), ('canada dry', 2), ('martini cocktail', 2), ('laban', 2), ('fruit tea', 2), ('alcoholic sake', 2), ('ramune', 2), ('water tea', 1), ('pepsiwater', 1), ('mineral water', 1), ('the avengers', 1), ('jarritos', 1), ('sake beer', 1), ('fish sauce', 1), ('boba', 1), ('none', 1), ('champagne', 1), ('gatorade', 1), ('sprindrift', 1), ('smoothie', 1), ('coffee', 1), ('yogurt', 1), ('leban', 1), ('dairy', 1), ('powerade', 1), ('mango pulp', 1), ('diet brisk', 1), ('yakult', 1), ('saporo', 1), ('soy sauce', 1), ('baijiu', 1), ('any tea', 1)]

# %%
#### go through the large_entries and pick out which of the labels appears first
# once you figure out which label appears first, replace the entry with that label

labels = [pair[0] for pair in label_freqs]
print("before\n")
print(large_entries)  # to see the before and after, you have to re-run everything (otherwise this is referencing the new one)

for index, row in large_entries.iterrows():
    entry = clean_text(row['drinks'])
    words = entry.split()
    # iterate through labels, finds the first one that appears in words
    matched = False
    for label in labels:
        if label in words:
            # easily found a match in existing labels
            large_entries.loc[index, 'drinks'] = label  # loc is from Pandas and allows us to directly modify specific rows/cols in df
            matched = True
            break

    if (not matched):
        # none of the labels appeared in this entry -- manually assign to "none"
        large_entries.loc[index, 'drinks'] = 'none'


large_entries.to_csv('/content/large_entries.csv', index=False) # Save to CSV
print("after\n")
print(large_entries)
# Out:
# before
#
#                                                  drinks  original_index
# 15                                       pop like coke               15
# 24                        soft drinks. for example, 7up              24
# 32                               coca-cola and iced tea              32
# 35    all sorts of carbonated drinks(e.g. coca-cola,...              35
# 57                                carbonated soft drink              57
# ...                                                 ...             ...
# 1614  i would pair bubble tea with sushi. mmmmm... b...            1614
# 1631                                      water or soup            1631
# 1635                               zero sugar coca cola            1635
# 1641         nothing in particular– probably just water            1641
# 1643  milk. especially if eaten with wasabi to put o...            1643
#
# [199 rows x 2 columns]
# after
#
#      drinks  original_index
# 15     coke              15
# 24      7up              24
# 32     none              32
# 35     none              35
# 57     none              57
# ...     ...             ...
# 1614   boba            1614
# 1631   soup            1631
# 1635   cola            1635
# 1641   none            1641
# 1643   milk            1643
#
# [199 rows x 2 columns]

# %%
#### add large_entries data into the cluster dataframe
for i, row in large_entries.iterrows():
    # extract data from this row
    drink_label = row['drinks']
    index = row['original_index']

    # iterate through refined_clusters to find which one has the matching label
    for cluster_id, words_indices in refined_clusters.items():
        cluster_words = [word for word, _ in words_indices]

        if drink_label in cluster_words:
            # this is the cluster that has this label
            refined_clusters[cluster_id].append((drink_label, index))  # add new data
            break

# Convert updated refined_clusters to DataFrame
cluster_data = []
for cluster_id, words_indices in refined_clusters.items():
    words = [word for word, idx in words_indices]
    indices = [idx for word, idx in words_indices]
    count = len(words)

    cluster_data.append([cluster_id, count, ", ".join(words), indices])  # Include cluster_id

# Create sorted DataFrame
cluster_df = pd.DataFrame(cluster_data, columns=['Cluster ID', 'Count', 'Cluster Words', 'Indices'])
cluster_df = cluster_df.sort_values(by='Count', ascending=False).reset_index(drop=True)  # Sort by Count

# Ensure indices are saved correctly
cluster_df["Indices"] = cluster_df["Indices"].apply(lambda x: [int(i) for i in x])

# Save to CSV
cluster_df.to_csv('/content/clusters1.csv', index=False)

# Print final results
print(cluster_df)
# Out:
#      Cluster ID  Count                                      Cluster Words  \
# 0   lemon water    321  lemon water, lemon water, water, water, water,...
# 1          coke    312  coke, coke, coke, coke, coke, coke, coke, coke...
# 2          soda    131  soda, soda, soda, soda, soda, soda, soda, soda...
# 3       ice tea    111  ice tea, ice tea, iced tea, ice tea, ice tea, ...
# 4          cola    111  cola, cola, cola, cola, cola, cola, cola, cola...
# ..          ...    ...                                                ...
# 64       yakult      1                                             yakult
# 65       saporo      1                                             saporo
# 66    soy sauce      1                                          soy sauce
# 67       baijiu      1                                             baijiu
# 68      any tea      1                                            any tea
#
#                                               Indices
# 0   [505, 634, 17, 61, 103, 121, 203, 240, 243, 24...
# 1   [0, 1, 6, 7, 9, 13, 18, 20, 22, 25, 29, 30, 37...
# 2   [3, 4, 5, 23, 43, 47, 50, 76, 78, 81, 89, 104,...
# 3   [11, 36, 174, 213, 277, 279, 305, 358, 419, 42...
# 4   [2, 27, 31, 65, 176, 222, 225, 272, 306, 417, ...
# ..                                                ...
# 64                                             [1512]
# 65                                             [1529]
# 66                                             [1541]
# 67                                             [1590]
# 68                                             [1642]
#
# [69 rows x 4 columns]

# %%
#### manually combining some clusters (ex. coke and cola) to further clean the labels
if "coke" in refined_clusters and "cola" in refined_clusters:
    refined_clusters["coke"].extend(refined_clusters["cola"])  # Merge "cola" into "coke"
    del refined_clusters["cola"]  # Remove the "cola" cluster

if "ice tea" in refined_clusters and "nestea" in refined_clusters:
    refined_clusters["ice tea"].extend(refined_clusters["nestea"])
    del refined_clusters["nestea"]

if "boba" in refined_clusters and "bubble tea" in refined_clusters:
    refined_clusters["boba"].extend(refined_clusters["bubble tea"])
    del refined_clusters["bubble tea"]

# if we didn't find a "sake" cluster_id, create one now -- trying to avoid grouping all of sake into water
if "sake" not in refined_clusters:
    refined_clusters["sake"] = []

# find the prospective labels that have "sake" in them
sake_merge_targets = [cluster_id for cluster_id in refined_clusters if "sake" in cluster_id and cluster_id != "sake"]

for cluster_id in sake_merge_targets:
    refined_clusters["sake"].extend(refined_clusters[cluster_id])  # Merge "cluster_id into "water"
    del refined_clusters[cluster_id]  # Remove the cluster_id cluster

# if we didn't find a "water" cluster_id, create one now -- we know there are lots of responses that have "water" but maybe not one that has a singular label
if "water" not in refined_clusters:
    refined_clusters["water"] = []

# find the prospective labels that have "water" in them
water_merge_targets = [cluster_id for cluster_id in refined_clusters if "water" in cluster_id and cluster_id != "water"]

for cluster_id in water_merge_targets:
    refined_clusters["water"].extend(refined_clusters[cluster_id])  # Merge "cluster_id into "water"
    del refined_clusters[cluster_id]  # Remove the cluster_id cluster

# Convert refined clusters to DataFrame
cluster_data = []
for cluster_id, words_indices in refined_clusters.items():
    words = [word for word, idx in words_indices]
    indices = [idx for word, idx in words_indices]
    count = len(words)

    cluster_data.append([cluster_id, count, ", ".join(words), indices])

cluster_df = pd.DataFrame(cluster_data, columns=['Cluster Id', 'Count', 'Cluster Words', 'Indices'])
cluster_df = cluster_df.sort_values(by='Count', ascending=False).reset_index(drop=True) #  use sort_values to reorder the clusters by count
cluster_df["Indices"] = cluster_df["Indices"].apply(lambda x: [int(i) for i in x])  # convert np.uint64 to int -- otherwise is weird in csv file
cluster_df.to_csv('/content/clusters2.csv', index=False) # save to csv

# Print results
print(cluster_df)

question = 'Q6: What drink would you pair with this food item?'
# Iterate through each row in all_res_mapping
for index, row in cluster_df.iterrows():
    ids = row['Indices']  # Get the list of IDs for this group
    label = row['Cluster Id']  # Get the label for this group

    # Iterate through each ID in the list
    for id in ids:
        # match the actual df row index with id
        match_index = df.index[df.index == id]

        # If a match is found, replace the 'question' column with the label
        if not match_index.empty:
            df.loc[match_index, question] = label

df = df.fillna('none')
df.to_csv('test_v2.csv', index=False)
# Out:
#           Cluster Id  Count  \
# 0               coke    423
# 1              water    333
# 2            ice tea    134
# 3               soda    131
# 4               none     99
# 5              juice     72
# 6             sprite     53
# 7         diet pepsi     45
# 8               sake     44
# 9          green tea     35
# 10              soup     32
# 11               pop     30
# 12        soft drink     21
# 13         root beer     19
# 14        ginger ale     17
# 15              milk     16
# 16          lemonade     14
# 17             ayran     11
# 18          red wine     11
# 19      orange fanta     10
# 20            matcha      7
# 21        barley tea      6
# 22              boba      6
# 23           hot tea      6
# 24          barbican      4
# 25             lassi      4
# 26        oolong tea      4
# 27            calpis      3
# 28               7up      3
# 29             crush      3
# 30          jarritos      2
# 31         lemon tea      2
# 32      mountain dew      2
# 33  carbonated drink      2
# 34         dr pepper      2
# 35            yogurt      2
# 36             laban      2
# 37            ramune      2
# 38         fruit tea      2
# 39        canada dry      2
# 40  martini cocktail      2
# 41   pineapple fanta      2
# 42      the avengers      1
# 43            coffee      1
# 44          smoothie      1
# 45          gatorade      1
# 46        sprindrift      1
# 47        fish sauce      1
# 48         champagne      1
# 49             leban      1
# 50             dairy      1
# 51        mango pulp      1
# 52          powerade      1
# 53        diet brisk      1
# 54            yakult      1
# 55         soy sauce      1
# 56            saporo      1
# 57           any tea      1
# 58            baijiu      1
#
#                                         Cluster Words  \
# 0   coke, coke, coke, coke, coke, coke, coke, coke...
# 1   lemon water, lemon water, water, water, water,...
# 2   ice tea, ice tea, iced tea, ice tea, ice tea, ...
# 3   soda, soda, soda, soda, soda, soda, soda, soda...
# 4   none, none, none, none, none, none, none, none...
# 5   juice, juice, juice, juice, juice, juice, juic...
# 6   sprite, sprite, sprite, sprite, sprite, sprite...
# 7   diet pepsi, diet pepsi, diet pepsi, diet pepsi...
# 8   water sake, sake, sake, sake, sake, sake, sake...
# 9   green tea, green tea, green tea, green tea, gr...
# 10  soup, soup, soup, soup, soup, soup, soup, miso...
# 11  pop, pop, pop, pop, pops, pop, pop, pop, pop, ...
# 12  soft drink, soft drink, soft drink, soft drink...
# 13  root beer, rootbeer, root beer, root beer, roo...
# 14  ginger ale, ginger ale, ginger ale, gingerale,...
# 15  milk, milk, milk tea, milk, milk tea, milk, mi...
# 16  lemonade, lemonade, lemonade, lemonade, lemona...
# 17  ayran, ayran, ayran, ayran, ayran, ayran, ayra...
# 18  red wine, wine, wine, wine, wine, wine, wine, ...
# 19  orange fanta, orange fanta, fanta, fanta, fant...
# 20  matcha, matcha, matcha, matcha tea, ocha, ocha...
# 21  barley tea, barley tea, barley tea, barley tea...
# 22  boba, boba, bubble tea, bubble tea, bubble tea...
# 23  hot tea, hot tea, hot tea, hot tea, hot tea, h...
# 24             barbican, barbican, barbican, barbican
# 25                   lassi, lassi, mango lassi, lassi
# 26     oolong tea, oolong tea, oolong tea, oolong tea
# 27                             calpis, calpis, calpis
# 28                                      7up, 7up, 7up
# 29                                crush, crush, crush
# 30                                 jarritos, jarritos
# 31                               lemon tea, lemon tea
# 32                         mountain dew, mountain dew
# 33                carbonated drink, carbonated drinks
# 34                               dr pepper, dr pepper
# 35                                     yogurt, yogurt
# 36                                       laban, laban
# 37                                     ramune, ramune
# 38                               fruit tea, fruit tea
# 39                             canada dry, canada dry
# 40                         martini cocktail, cocktail
# 41                   pineapple fanta, pineapple fanta
# 42                                       the avengers
# 43                                             coffee
# 44                                           smoothie
# 45                                           gatorade
# 46                                         sprindrift
# 47                                         fish sauce
# 48                                          champagne
# 49                                              leban
# 50                                              dairy
# 51                                         mango pulp
# 52                                           powerade
# 53                                         diet brisk
# 54                                             yakult
# 55                                          soy sauce
# 56                                             saporo
# 57                                            any tea
# 58                                             baijiu
#
#                                               Indices
# 0   [0, 1, 6, 7, 9, 13, 18, 20, 22, 25, 29, 30, 37...
# 1   [505, 634, 17, 61, 103, 121, 203, 240, 243, 24...
# 2   [11, 36, 174, 213, 277, 279, 305, 358, 419, 42...
# 3   [3, 4, 5, 23, 43, 47, 50, 76, 78, 81, 89, 104,...
# 4   [675, 32, 35, 57, 82, 83, 146, 150, 163, 187, ...
# 5   [75, 244, 251, 260, 303, 315, 338, 421, 535, 5...
# 6   [16, 70, 111, 166, 231, 238, 274, 278, 308, 31...
# 7   [52, 826, 866, 967, 1173, 69, 115, 137, 376, 4...
# 8   [1552, 496, 504, 507, 521, 533, 573, 586, 591,...
# 9   [497, 502, 510, 532, 548, 552, 558, 566, 569, ...
# 10  [19, 501, 525, 1479, 1508, 1624, 1639, 482, 48...
# 11  [132, 155, 160, 182, 185, 192, 373, 396, 401, ...
# 12  [122, 138, 148, 199, 265, 379, 440, 773, 917, ...
# 13  [21, 183, 228, 262, 469, 503, 724, 1312, 1608,...
# 14  [162, 205, 259, 360, 437, 782, 798, 802, 945, ...
# 15  [165, 180, 268, 551, 647, 1296, 1341, 1386, 14...
# 16  [12, 184, 346, 366, 405, 1183, 1225, 1313, 132...
# 17  [245, 261, 324, 447, 1092, 1096, 1215, 1218, 1...
# 18  [14, 131, 407, 590, 599, 602, 1101, 639, 1339,...
# 19  [41, 339, 410, 412, 787, 914, 1114, 1231, 1247...
# 20            [579, 625, 1429, 1491, 592, 1612, 1423]
# 21                 [520, 650, 1385, 1440, 1463, 1519]
# 22                   [644, 1614, 198, 632, 715, 1456]
# 23                   [530, 534, 536, 660, 1455, 1558]
# 24                           [1194, 1203, 1230, 1306]
# 25                              [284, 458, 1319, 387]
# 26                               [495, 655, 682, 698]
# 27                                    [512, 605, 653]
# 28                                    [725, 1190, 24]
# 29                                   [731, 1038, 736]
# 30                                        [457, 1367]
# 31                                         [242, 712]
# 32                                          [44, 921]
# 33                                         [295, 465]
# 34                                        [112, 1005]
# 35                                       [1197, 1061]
# 36                                       [1058, 1189]
# 37                                       [1473, 1496]
# 38                                       [1286, 1593]
# 39                                        [790, 1007]
# 40                                        [895, 1565]
# 41                                        [737, 1044]
# 42                                              [369]
# 43                                             [1078]
# 44                                             [1030]
# 45                                              [794]
# 46                                              [877]
# 47                                              [549]
# 48                                              [696]
# 49                                             [1237]
# 50                                             [1324]
# 51                                             [1478]
# 52                                             [1408]
# 53                                             [1492]
# 54                                             [1512]
# 55                                             [1541]
# 56                                             [1529]
# 57                                             [1642]
# 58                                             [1590]

# %%
# # last min kar adjustemnts
# q5='Q5: What movie do you think of when thinking of this food item?'
# df[q5] = df[q5].apply(clean_text)

# unique_values = df[q5].unique().tolist()

# from pprint import pprint
# pprint(unique_values)


# df[q5] = df[q5].str.lower()
# df[question] = df[question].str.lower()

# forced_spiderman = ['spider man 2', 'spiderman', 'spider man', 'spiderman with tobey maguire',  'spiderman 2', 'spider man spider verse',]
# forced_avengers = ['the avengers', 'avengers 1','avenegers',  'the avengers action movies',
# 'the avengers postcredit scene', 'avangers','avengers age of ultron', 'avengers age of ultron',
#  'avenger', 'avenger', 'the avengers action movies', 'marvel movies', 'endgame',  'avengers',  'avengers endgame', 'the avengers 2012',]
# forced_teens = [ 'teenage mutant ninja turtle',   'ninja turtle','tnmt','ninja turtle',  'ninja turtles', 'teenage mutant ninja turtles', 'avengers end game',]
# i_hate_you = [ 'none', 'idk',  'no movie',  'no movie comes to mind', 'not sure', 'none specifically', 'nothing',
#  'i dont', 'i cant think of anything', '',  'i dont know', 'no', 'scific movies', 'no', 'none come to mind', 'no but i think japan',
#  'i dont know', 'none in particular', 'na', 'nothing comes to mind', 'none specifically',]
# froced_deadpool=['deadpool', 'deadpool 3', 'deadpool 2', 'deadpool vs wolverine',  'deadpool wolverine',]
# forced_sponge = [  'spongebob', 'the spongebob movie 2004']
# forced_poke=[ 'pokemon the first movie', 'pokemon']
# forced_pizza = [ 'pizza', 'pizza 2012',]
# forced_fnaf = [ 'five nights at freddies', 'five nights at freddys',]
# forced_iron_man = [ 'iron man', 'iron man i',]
# froced_home_alon = [ 'i think of home alone', 'home alone', 'home alone 2', 'home alone or action movies', 'homealone',]
# f_fnf = [ 'fast and furious', 'fast and furious tokyo drift',  'tokyo drift',]
# mario=[ 'mario movie', 'the mario movie',]
# nemo=[ 'findig nemo', 'nemo',]
# your_nae=[ 'your name 2016',]
# j_W = [ 'john wick 3', 'john wick chapter 4',]
# alessia = [ 'the italian job','italian movie', 'italian jon',] # italian job
# mib = [ 'men in black','mib',  'man in black',]
# misison_impossible=[ 'action movie like mission impossible',]


# df[q5] = df[q5].replace(forced_spiderman, 'spiderman')
# df[q5] = df[q5].replace(forced_avengers, 'the avengers')
# df[q5] = df[q5].replace(forced_teens, 'teenage mutant ninja turtles')
# df[q5] = df[q5].replace(i_hate_you, 'none')
# df[q5] = df[q5].replace(froced_deadpool, 'deadpool')
# df[q5] = df[q5].replace(forced_sponge, 'spongebob')
# df[q5] = df[q5].replace(forced_poke, 'pokemon')
# df[q5] = df[q5].replace(forced_pizza, 'pizza')
# df[q5] = df[q5].replace(forced_fnaf, 'five nights at freddys')
# df[q5] = df[q5].replace(forced_iron_man, 'iron man')
# df[q5] = df[q5].replace(froced_home_alon, 'home alone')
# df[q5] = df[q5].replace(f_fnf, 'fast and furious')
# df[q5] = df[q5].replace(mario, 'mario movie')
# df[q5] = df[q5].replace(nemo, 'finding nemo')
# df[q5] = df[q5].replace(j_W, 'john wick')
# df[q5] = df[q5].replace(alessia, 'the italian job')
# df[q5] = df[q5].replace(mib, 'men in black')
# df[q5] = df[q5].replace(misison_impossible, 'mission impossible')

# ##### repeats  #######

# question='Q5: What movie do you think of when thinking of this food item?'
# q5 = df[['id', question]]

# # Extract the 'id' column and the responses
# ids = q5['id']  # Store the 'id' column
# responses = q5[question]  # Extract only the responses

# # Reset the index of the responses Series
# responses = responses.reset_index(drop=True)  # Reset index to 0, 1, 2, ...

# # Compute the similarity matrix using Jaro-Winkler similarity
# threshold = 0.87
# similarity_matrix = compute_similarity_matrix(
#     responses, jellyfish.jaro_winkler_similarity, threshold
# )

# # Identify clusters using connected components
# n_components, labels = connected_components(csgraph=similarity_matrix, directed=False)

# # Group responses and their corresponding IDs based on clusters
# clusters = {}
# for i, label in enumerate(labels):
#     if label not in clusters:
#         clusters[label] = {'responses': [], 'ids': []}
#     clusters[label]['responses'].append(responses[i])  # Store the response
#     clusters[label]['ids'].append(ids.iloc[i])  # Store the corresponding ID


# # Convert clusters into a DataFrame
# cluster_data = []
# for cluster_id, group in clusters.items():
#     cluster_data.append({
#         'Cluster ID': cluster_id,
#         'Responses': ', '.join(group['responses']),  # Combine responses into a single string
#         'IDs': ', '.join(map(str, group['ids'])),  # Combine IDs into a single string
#         'Number of Responses': len(group['responses'])  # Add count of responses in the cluster
#     })

# # Create the DataFrame
# clusters_df = pd.DataFrame(cluster_data)
# clusters_df = clusters_df.sort_values(by='Number of Responses', ascending=False)
# # Apply the function to the 'Responses' column to create the 'Label' column
# clusters_df['Label'] = clusters_df['Responses'].apply(ensure_list).apply(find_median_length_string)


# # Iterate through each row in all_res_mapping
# for index, row in clusters_df.iterrows():
#     ids = row['IDs']  # Get the list of IDs for this group
#     label = row['Label']  # Get the label for this group

#     # Iterate through each ID in the list
#     for id in ids:
#         # Find the row in qq where the 'id' column matches the current ID
#         match_index = df[df['id'] == id].index

#         # If a match is found, replace the 'question' column with the label
#         if not match_index.empty:
#             df.loc[match_index, question] = label

# df = df.fillna('none')

# df.to_csv('/content/clusters3.csv', index=False) # save to csv

# %%
# # Iterate through each row in all_res_mapping
# for index, row in all_res_mapping.iterrows():
#     ids = row['IDs']  # Get the list of IDs for this group
#     label = row['Label']  # Get the label for this group

#     # Iterate through each ID in the list
#     for id in ids:
#         # Find the row in qq where the 'id' column matches the current ID
#         match_index = model_df[model_df['id'] == id].index

#         # If a match is found, replace the 'question' column with the label
#         if not match_index.empty:
#             model_df.loc[match_index, question] = label

# model_df = model_df.fillna('None')


# # Save the updated qq DataFrame to a CSV file (optional)
# model_df.to_csv('/content/updated_qq.csv', index=False)

# %%
# !pip install pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import jellyfish
from scipy.sparse.csgraph import connected_components
from scipy.spatial.distance import squareform



def clean_text(text):
    # Remove non-alphanumeric characters except spaces
    cleaned = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    # Normalize spaces (replace multiple spaces with a single space)
    cleaned = re.sub(r'\s+', ' ', cleaned).strip()
    return cleaned

model_df = pd.read_csv('test_v2.csv')
question = 'Q5: What movie do you think of when thinking of this food item?'




# filtering manually
forced_spiderman = ['into the spiderverse', 'spiderman just cause it takes place in new york', 'i think of spiderman when thinking of this food item','spider man 2','sam raimis spider man',  'i think of the spiderman movie', 'spiderman', 'spider man', 'spiderman with tobey maguire',  'spiderman 2', 'spiderman 2002 starring tobey maguire']
forced_avengers = ['the avengers', 'i think of the avengers when i think of shawarma',
'i think of the avengers when thinking of this food item', 'i dont usually think of any movie when having this food item but after using google to refresh my memory i would say avengers because of the postcredits scene','i think of the movie the avengers because in the final scene of the movie tony stark takes the avengers to the shawarma place',
'i think about the movie avengers when i think of shawarma','i think of the movie named avengers', 'i think of the movie the avengers','i think of the movie the avengers they have an entire bit surrounding this food item', 'avengers end game', 'avengers 1','avenegers',  'the avengers action movies',
'the avengers postcredit scene', 'avangers','avengers age of ultron', 'avengers age of ultron','marvel avengers', 'marvels avengers','advengers 2012 movie', 'avengers 2012',
 'avenger', 'avenger', 'that one marvel movie i dont know i dont watch movies','not exactly movies but i would prefer to watch some tv series when i am having pizzas if movies specifically i may think of cartoon movies or more heromarvel related ones like teenage mutant ninja turtles movies in marvel series etc',
                   'the avengers because they eat it together after the battle of new york',
                   'the avengers movie when they eat shawarma in the end credits scene','avengers because of iron man asking everyone to get shawarma after the fight',
                   'the only movie that is associated with this food item would be the first avengers due to the post credit scene',
'the avengers at the end of the film after the battle in nyc tony stark suggests to the rest of the team that they go get shawarma'	,
                   'the avengers action movies', 'marvel movies', 'endgame',  'avengers',  'avengers endgame', 'the avengers 2012']
forced_teens = [ 'teenage mutant ninja turtle', 'rise of the teenage mutant ninja turtles the movie 2022',
                'teenage mutant ninja turtles vs batman the tmnt love pizza and they eat it with batman at the end of the movie',
                'i think of the ninja turtle movies when thinking of pizza', 'the teenage mutant ninja turtles', 'ninja turtle','tnmt','ninja turtle',  'ninja turtles', 'teenage mutant ninja turtles',  'any teenage mutant ninja turtle movie', 'inside out teenage mutant ninja turtles']
i_hate_you = [ 'none', 'none ok tbf i think of my life at uoft if life is a movie','no movies come to mind', 'no movie came up to my mind','idk', 'i actually can not think of anything', 'no movie', 'no movie comes to mind', 'not sure', 'none specifically', 'nothing',
 'i dont', 'i cant think of anything', '', 'no movies come to mind',  'i dont know', 'no', 'scific movies', 'no', 'none come to mind', 'no but i think japan', 'i dont think of any movie', 'i dont think of any movie', 'i dont think of a movie', 'i dont watch movies',
 'i dont know', 'none in particular', 'na', 'na i only watched a few movies so i cannot think of any movie related to pizza',
'na i only watched a few movies so i cannot think of any movie related to shawarma', 'i dont have a movie i think of when i think of pizza',
               'ive never had them before attending u of t so i dont associate them with anything',
'na i only watched a few movies so i cannot think of any movie related to sushi',	'none stranger things is the tv series i can think of',
'na i dont watch a lot of movies', 'i dont know that many movies fr','i have no idea i dont eat that stuff',
'na i dont watch a lot of movies', 'i think about the first avengers movie after they fought off the aliens in the city the superheroes gather at a local shawarma place that is nearly destroyed because of the alien invasion and eat quietly around the table',
'na i dont watch a lot of movies', 'i dont have a movie i think of when i think of sushi','i dont think of a movie when thinking of this food item','i dont think of any movie pizza pairs well with any movie',
               'i might think of some short ones or simply videos as when i am having shawarma i do not usually have much time and the food is some hands size so people can usually finish it up quickly so i would say no movieshort ones like monster inc',
               'probably some niche movie or some movie specific to a country and not an english movie',
               'nothing comes to mind', 'no movie that i can think','none specifically']
froced_deadpool=['deadpool', 'deadpool 3', 'deadpool 2','deadpool wolverine is the movie that comes to mind this is because of the ending scene where they get this food after their battle',

                 'deadpool vs wolverine',  'deadpool wolverine']
forced_sponge = [  'spongebob', 'the spongebob movie 2004']
forced_poke=[ 'pokemon the first movie', 'pokemon']
forced_pizza = [ 'pizza', 'pizza 2012', 'honestly any movie pizza is a movie food', 'i think about a nice chill movie with pizza maybe something like hangover']
forced_fnaf = [ 'five nights at freddies', 'five nights at freddys']
forced_iron_man = [ 'iron man', 'iron man i']
froced_home_alon = [ 'i think of home alone', 'for some reason home alone is the first thing that came to mind',
                    'i usually associate this item with the winter because school parties would frequently order this food item hence i would say the polar express elf and home alone',
                    'home alone because kevin orders an entire one for himself','home alone when the delivery guy delivers a cheese pizza little neros pizza through the back door for kevin when he gets stuck home alone',
                     """home alone is the first movie that comes to minds im referring to the scene were the whole family order 10 boxes of pizza and their trying to see who is going to pay""",'i think about about the movie home alone','home alone', 'home alone 2 lost in new york', 'home alone 2 lost in new york','home alone 2', 'home alone or action movies', 'homealone']
f_fnf = [ 'fast and furious', 'fast and furious tokyo drift',  'tokyo drift']
mario=[ 'mario movie', 'the mario movie']
nemo=[ 'findig nemo', 'nemo', 'finding nemo was the first movie in my mind']
your_nae=[ 'your name 2016']
j_W = [ 'john wick 3', 'john wick chapter 4', 'john wick chapter 3 parabellum', 'john wick chapter 3 parabellum']
alessia = [ 'the italian job','italian movie', 'italian jon', 'i think of the movie little italy the entire plot revolves around two individuals who are competing in a restaurant business where their primary product is this food item'] # italian job
mib = [ 'men in black','mib',  'man in black']
misison_impossible=[ 'action movie like mission impossible']
borat=['i think of the movie borat']
wolv = ['the wolverine', 'the wolverine', 'the wolverine', 'the wolverine','wolverine']

jap = ['any japanese movie and animes', 'tokyo story 1953', 'tokyo story', 'a japanese anime movie such as spirited away',
       'some japanese movie or some action movie', 'spirited away or any japanese movie in general',
       'i think of ninja movies with i think of sushi especially japanese anime ninja movies','i dont think of any movies i think of anime',
       'sushi is from japan so i would think about a japanese movie your name the anime movie', 'almost all asian movies especially japanese not any movie in particular comes in mind'

       ]
spiderverse=['into the spiderverse', ]
totoro=['some ghibli movie', ]
lionking=['mufasa the lion king']
harry=['harry potter the philosophers stone', 'i watched the harry potter series with my friends while eating sushi so i associate sushi with harry potter']
bruh = ['something fun like superbad']
sushi=['dreams of sushi', 'i might came up with some japan related movieslike jiro dreams of sushi this is in fact a documentarycartoonslike tv series like the solitary gourmet',
       'i think of the movie jiro dreams of sushi', 'i think of the movie jiro dreams of sushi it is a movie about an 85 year old sushi master behind a three michelin star sushi restaurant and his sons who are set to take over the business']
pasgetti = ['spaghetti with a chance of meatballs', 'i think of the movie cloudy with a chance of meatballs', 'i think of the movie cloudy with a chance of meatballs because i associate pizza with popular italian cuisine and meatballs is italian cuisine']
garfield=['the garfield movie', 'the garfield movie']


print(model_df[question].value_counts())

model_df[question] = model_df[question].astype(str)
model_df[question] = model_df[question].str.lower()
model_df[question] = model_df[question].apply(lambda x: clean_text(str(x)) if pd.notnull(x) else '')

model_df[question] = model_df[question].replace(forced_spiderman, 'spiderman')
model_df[question] = model_df[question].replace(forced_avengers, 'the avengers')
model_df[question] = model_df[question].replace(forced_teens, 'teenage mutant ninja turtles')
model_df[question] = model_df[question].replace(i_hate_you, 'none')
model_df[question] = model_df[question].replace(froced_deadpool, 'deadpool')
model_df[question] = model_df[question].replace(forced_sponge, 'spongebob')
model_df[question] = model_df[question].replace(forced_poke, 'pokemon')
model_df[question] = model_df[question].replace(forced_pizza, 'pizza')
model_df[question] = model_df[question].replace(forced_fnaf, 'five nights at freddys')
model_df[question] = model_df[question].replace(forced_iron_man, 'iron man')
model_df[question] = model_df[question].replace(froced_home_alon, 'home alone')
model_df[question] = model_df[question].replace(f_fnf, 'fast and furious')
model_df[question] = model_df[question].replace(mario, 'mario movie')
model_df[question] = model_df[question].replace(nemo, 'finding nemo')
model_df[question] = model_df[question].replace(j_W, 'john wick')
model_df[question] = model_df[question].replace(alessia, 'the italian job')
model_df[question] = model_df[question].replace(mib, 'men in black')
model_df[question] = model_df[question].replace(misison_impossible, 'mission impossible')
model_df.loc[:, question] = model_df[question].replace('i think of the movie borat', 'borat')
model_df[question] = model_df[question].replace(wolv, 'wolverine')
model_df[question] = model_df[question].replace(jap, 'japanese')
model_df[question] = model_df[question].replace(totoro, 'totoro')
model_df[question] = model_df[question].replace(lionking, 'lion king')
model_df[question] = model_df[question].replace(harry, 'harry potter')
model_df[question] = model_df[question].replace(bruh, 'superbad')
model_df[question] = model_df[question].replace(sushi, 'jiro dreams of sushi')
model_df[question] = model_df[question].replace(pasgetti, 'cloudy with a chance of meatball')
model_df[question] = model_df[question].replace(garfield, 'garfield')



ratatouil=[
    """ it sounds like youre referring to the movie ratatouille its a pixar animated film about a rat named remy who dreams of becoming a great chef despite being a rodent in a profession dominated by humans the story is set in paris and it beautifully blends themes of passion creativity and perseverance in the culinary world let me know if this is the one youre thinking of""",
    'rattatouie even though there isnt pizza','ratatouille again but thats because my knowledge of movies is limited and i barely watch any',
           'ratatouille because the rat is italian and italians like pizza', 'i think about the movie ratatouille as it took place in italy and pizza reminds me of italy',
            'ratatouille because sushi needs to be sliced and they slice food in ratatouille',
            'ratatouille because the rat cooks food and this is food','it sounds like youre referring to the movie ratatouille its a pixar animated film about a rat named remy who dreams of becoming a great chef despite being a rodent in a profession dominated by humans the story is set in paris and it beautifully blends themes of passion creativity and perseverance in the culinary world let me know if this is the one youre thinking of, it sounds like youre referring to the movie ratatouille its a pixar animated film about a rat named remy who dreams of becoming a great chef despite being a rodent in a profession dominated by humans the story is set in paris and it beautifully blends themes of passion creativity and perseverance in the culinary world let me know if this is the one youre thinking of, it sounds like youre referring to the movie ratatouille its a pixar animated film about a rat named remy who dreams of becoming a great chef despite being a rodent in a profession dominated by humans the story is set in paris and it beautifully blends themes of passion creativity and perseverance in the culinary world let me know if this is the one youre thinking of']
ur_name=['i think of the movie your name', 'i think of your name when thinking of this food item',]
mulan=['think of mulan which my family and i watched last weekend while eating shawarma']

bigbigwolf=['i would associate it with movie series like pleasant goat and big big wolf as that was one of the childhood shows i watched from the time when we could sometimes go and eat out as a family']
thebigshort=['the movie that comes to mind for this food item is the big short there is one scene that is very vivid and eyeopening conversations when it comes to the fault of hedge funds during the 2008 crisis that was discussed over this food item']
starwqrs=['star wars episode v the empire strikes back']
scottpilgtam=['i think of movies that take place in toronto since its so common here such as scott pilgrim vs the world']

#	middle east movie
middle_east=['probably something with a middle eastern setting', 'i think of middle easternindian movies but nothing some in mind specifically',
             'probably some middle eat movies', 'those commercials by the toronto food man za bebsi is the best']
legendshawrama=['none only thing i know about it is the game shawarma legend', 'not suremaybe turkish movies but it will remind me of a game called shawarma legend which is a simulation game and highly recommended',
                'cant think of any dont have an idea about the taste of shawarma and havent seen it in any movie that ive watched']
shrekkk=['i think about movies like holes or shrek since it reminds me of the movies teachers would put on for us during school events',
         'when eating pizza i think of the movie shrek 2', 'when eating shawarma i think of the movie shrek 2', 'when eating sushi i think of the movie shrek 2']
chef=['i think of the movie chef2014 as it was very foodrelated and had a lot of ovenbaked goods','i think of the movie named chef',  'we live in time in one of the scenes the chef is making sushi i watched it recently']
food_wars =['i thought of the anime food wars', 'i think of the anime food wars']
jaws=['i think of the movie jaws because sushi is fish and jaws is a movie about shark which is a fish']
cheech_chong=['i think of the cheech chong movies when i think of shawarma']
goodtime=['i think about the movie good time when thinking of this food item']
isledogs = ['isle of dogs this film showcases a chef making a poisoned sushi']
brkfast=['breakfast club one of the characters gets into an argument with someone else if eating sushi is allowed']
brkabad=['i actually think of the series breaking bad and that famous scene where walter flips out']
docs = ['bbc food channels movies and documentaries']

penguinismagdas=['penguins of madagascar there was a scene where all penguins made sushi and had to fight a big purple octopus with it']
cars=['i think of cars 2 when thinking of this food item this is because of the scene where tow mater mistakes wasabi a popular topping for this food item for pistachio ice cream with comical results']
toystory=['toy story the restaurant that the green aliens come from serve it the name of the restaurant is an alliteration with the last word of the name being planet']
malena=['when thinking of pizza it would reminder me of italy and the first movie that came to mind was malena']
minions=['to be honest i cant really think of any movie but if i have to answer i would say minions rise of gru']
gilmore_girls=['i think of the show gilmore girls theyre always eating pizza']
goodfellas=['goodfellas there is a restaurant that sells pizza and is goodfellas themed']
cartoons=['im thinking of cartoons and mostly western based cartoon though i cant think of anything specific but mostly western cartoon movies']
godfather=['i think of italian mobster movies like the godfather']

bruhh=['it sounds like youre referring to the movie ratatouille its a pixar animated film about a rat named remy who dreams of becoming a great chef despite being a rodent in a profession dominated by humans the story is set in paris and it beautifully blends themes of passion creativity and perseverance in the culinary world let me know if this is the one youre thinking of']

model_df[question] = model_df[question].replace(bruhh, 'ratatouille')
model_df[question] = model_df[question].replace(ratatouil, 'ratatouille')
model_df[question] = model_df[question].replace(ur_name, 'your name')
model_df[question] = model_df[question].replace(mulan, 'mulan')
model_df[question] = model_df[question].replace(bigbigwolf, 'big big wolf')
model_df[question] = model_df[question].replace(thebigshort, 'the big short')
model_df[question] = model_df[question].replace(starwqrs, 'star wars')
model_df[question] = model_df[question].replace(scottpilgtam, 'scott pilgrim vs the world')
model_df[question] = model_df[question].replace(middle_east, 'middle east movie')
model_df[question] = model_df[question].replace(legendshawrama, 'shawarma legend')
model_df[question] = model_df[question].replace(shrekkk, 'shrek')
model_df[question] = model_df[question].replace(chef, 'chef')
model_df[question] = model_df[question].replace(food_wars, 'food wars')
model_df[question] = model_df[question].replace(jaws, 'jaws')
model_df[question] = model_df[question].replace(cheech_chong, 'cheech chong')
model_df[question] = model_df[question].replace(goodtime, 'good time')
model_df[question] = model_df[question].replace(isledogs, 'isle of dogs')
model_df[question] = model_df[question].replace(brkfast, 'breakfast club')
model_df[question] = model_df[question].replace(brkabad, 'breaking bad')
model_df[question] = model_df[question].replace(docs, 'documentary')
model_df[question] = model_df[question].replace(penguinismagdas, 'pengnuins of madagascar')
model_df[question] = model_df[question].replace(cars, 'cars')
model_df[question] = model_df[question].replace(toystory, 'toy story')
model_df[question] = model_df[question].replace(malena, 'malena')
model_df[question] = model_df[question].replace(minions, 'minions')
model_df[question] = model_df[question].replace(gilmore_girls, 'gilmore girls')
model_df[question] = model_df[question].replace(goodfellas, 'goodfellas')
model_df[question] = model_df[question].replace(cartoons, 'cartoons')
model_df[question] = model_df[question].replace(godfather, 'the godfather')





print(model_df[question].value_counts())

q5 = model_df[['id', question]]

q5[question] = q5[question].str.lower()
q5[question] = q5[question].astype(str)
q5['word_count'] = q5[question].str.split().str.len()
q5 = q5.sort_values(by='word_count', ascending=False)  # Use ascending=True for increasing order


# divide based on median, so we divide the yapping rants vs actual titles (assuming its likely chances)
# actually, not very satisfied with this median length....
word_lengths = q5[question].str.split().explode().str.len()
median_word_length = word_lengths.quantile(0.5)
print(median_word_length)

# ... we did more exploration
# Compute the median word length across the entire column
median_word_length = word_lengths.quantile(0.95)
print(median_word_length)

# Count the occurrences of each word length
word_length_counts = word_lengths.value_counts().sort_index()

# Plot the counts for each word length
plt.figure(figsize=(14, 6))  # Increase figure width to provide more space
bars = plt.bar(word_length_counts.index, word_length_counts.values, color='skyblue')
plt.title("Distribution of Word Lengths", fontsize=16)
plt.xlabel("Word Length", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.xticks(range(1, 35), rotation=45, ha='right', fontsize=10)  # Rotate labels and align them to the right
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()  # Adjust layout to prevent label overlap
plt.show()

# Export the DataFrame to a CSV file
# analyzing this shows us that from 6-7 words is split between real movie
# names and long answers. Will use the cut-off of 6<= words for the first part
# of processing and >6 that has additional processing
q5.to_csv('/content/word_counted_responses.csv', index=False)
# Out:
# Q5: What movie do you think of when thinking of this food item?
# The Avengers                                                                                                 107
# none                                                                                                          78
# Avengers                                                                                                      65
# Home Alone                                                                                                    42
# Teenage Mutant Ninja Turtles                                                                                  38
#                                                                                                             ...
# Into the Spiderverse                                                                                           1
# shang chi                                                                                                      1
# Breakfast club (One of the characters gets into an argument with someone else if eating sushi is allowed)      1
# Heretic                                                                                                        1
# Crayon Shinchan                                                                                                1
# Name: count, Length: 769, dtype: int64
# Q5: What movie do you think of when thinking of this food item?
# the avengers                    252
# none                            153
# home alone                       69
# teenage mutant ninja turtles     68
# spiderman                        60
#                                ...
# good time                         1
# who am i 2005                     1
# memory of a geisha                1
# last samurai                      1
# dead silence                      1
# Name: count, Length: 431, dtype: int64
# 5.0
# 9.0
# <ipython-input-23-6f302e449c56>:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   q5[question] = q5[question].str.lower()
# <ipython-input-23-6f302e449c56>:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   q5[question] = q5[question].astype(str)
# <ipython-input-23-6f302e449c56>:212: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   q5['word_count'] = q5[question].str.split().str.len()

# %%
# """
# Now let's start classifying based on the data set:
# """

# Extract the 'id' column and the responses
ids = q5[q5['word_count'] < 7]['id']  # Store the 'id' column
responses = q5[q5['word_count'] < 7][question]  # Extract only the responses

# Reset the index of the responses Series
responses = responses.reset_index(drop=True)  # Reset index to 0, 1, 2, ...
responses = responses.apply(clean_text)


# Function to compute the similarity matrix
def compute_similarity_matrix(responses, similarity_func, threshold):
    n = len(responses)
    similarity_matrix = np.zeros((n, n))

    # Vectorized computation of pairwise similarities
    for i in range(n):
        for j in range(i+1, n):  # Only compute upper triangle
            similarity = similarity_func(responses[i], responses[j])
            if similarity >= threshold:
                similarity_matrix[i, j] = 1
                similarity_matrix[j, i] = 1  # Symmetric

    return similarity_matrix

# Compute the similarity matrix using Jaro-Winkler similarity
threshold = 0.87
similarity_matrix = compute_similarity_matrix(
    responses, jellyfish.jaro_winkler_similarity, threshold
)

# Identify clusters using connected components
n_components, labels = connected_components(csgraph=similarity_matrix, directed=False)

# Group responses and their corresponding IDs based on clusters
clusters = {}
for i, label in enumerate(labels):
    if label not in clusters:
        clusters[label] = {'responses': [], 'ids': []}
    clusters[label]['responses'].append(responses[i])  # Store the response
    clusters[label]['ids'].append(ids.iloc[i])  # Store the corresponding ID

############## for analysis ################

# Output clusters
for cluster_id, group in clusters.items():
    print(f"Group {cluster_id}: Responses: {group['responses']}, IDs: {group['ids']}")

# Convert clusters into a DataFrame
cluster_data = []
for cluster_id, group in clusters.items():
    cluster_data.append({
        'Cluster ID': cluster_id,
        'Responses': ', '.join(group['responses']),  # Combine responses into a single string
        'IDs': ', '.join(map(str, group['ids'])),  # Combine IDs into a single string
        'Number of Responses': len(group['responses'])  # Add count of responses in the cluster
    })

# Create the DataFrame
clusters_df = pd.DataFrame(cluster_data)
clusters_df = clusters_df.sort_values(by='Number of Responses', ascending=False)

# Save the DataFrame to a CSV file
clusters_df.to_csv('workin_smaller_class.csv', index=False)
# Out:
# Group 0: Responses: ['cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatball', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatball', 'cloudy with a chance of meatball', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatball', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs'], IDs: [np.int64(389109), np.int64(727339), np.int64(494373), np.int64(632125), np.int64(712252), np.int64(716549), np.int64(626792), np.int64(631436), np.int64(502610), np.int64(505318), np.int64(630044), np.int64(631221), np.int64(630972), np.int64(603582), np.int64(605254), np.int64(204508), np.int64(629700), np.int64(629142), np.int64(607160), np.int64(715845), np.int64(497421), np.int64(632299), np.int64(603476), np.int64(714901), np.int64(629072), np.int64(419835), np.int64(630928), np.int64(634825), np.int64(633520)]
# Group 1: Responses: ['you dont mess with the zohan', 'you dont mess with the zohan'], IDs: [np.int64(608318), np.int64(628102)]
# Group 2: Responses: ['any movie set in new york'], IDs: [np.int64(619932)]
# Group 3: Responses: ['eternal sunshine of the spotless mind'], IDs: [np.int64(728522)]
# Group 4: Responses: ['a goofy movie the disney movie'], IDs: [np.int64(289931)]
# Group 5: Responses: ['once upon a time in hollywood'], IDs: [np.int64(387155)]
# Group 6: Responses: ['a quiet place day one 2024', 'a quiet place 2'], IDs: [np.int64(631507), np.int64(631216)]
# Group 7: Responses: ['harold kumar go to white castle'], IDs: [np.int64(13183)]
# Group 8: Responses: ['back to the future part 2', 'back to the future 2', 'back to the future', 'back to the future', 'back to the future', 'back to the future', 'back to the future'], IDs: [np.int64(629758), np.int64(500077), np.int64(502799), np.int64(606821), np.int64(634468), np.int64(306207), np.int64(631531)]
# Group 9: Responses: ['south park the end of obesity'], IDs: [np.int64(296589)]
# Group 10: Responses: ['mission impossible dead reckoning part one', 'mission impossible', 'mission impossible', 'mission impossible', 'mission impossible'], IDs: [np.int64(601848), np.int64(627220), np.int64(711854), np.int64(601737), np.int64(607609)]
# Group 11: Responses: ['breaking bad not a movie', 'breaking bad', 'breaking bad', 'breaking bad', 'breaking bad', 'breaking bad', 'breaking bad'], IDs: [np.int64(717116), np.int64(608554), np.int64(628077), np.int64(524803), np.int64(609617), np.int64(606010), np.int64(519570)]
# Group 12: Responses: ['scott pilgrim vs the world', 'scott pilgrim vs the world', 'scott pilgrim vs the world', 'scott pilgrim'], IDs: [np.int64(617029), np.int64(413014), np.int64(603415), np.int64(390823)]
# Group 13: Responses: ['everything everywhere all at once', 'everything everywhere all at once'], IDs: [np.int64(712702), np.int64(519681)]
# Group 14: Responses: ['the super mario bros movie'], IDs: [np.int64(630227)]
# Group 15: Responses: ['the boy and the herron', 'the boy and the heron'], IDs: [np.int64(519822), np.int64(601363)]
# Group 16: Responses: ['wizards of waverly place movie'], IDs: [np.int64(387330)]
# Group 17: Responses: ['diary of a wimpy kid'], IDs: [np.int64(620745)]
# Group 18: Responses: ['who am i jackie chan'], IDs: [np.int64(306207)]
# Group 19: Responses: ['murder on the orient express'], IDs: [np.int64(520303)]
# Group 20: Responses: ['little forest a japanese film'], IDs: [np.int64(501893)]
# Group 21: Responses: ['liz and the blue bird'], IDs: [np.int64(627427)]
# Group 22: Responses: ['princess diaries the apology scene'], IDs: [np.int64(601945)]
# Group 23: Responses: ['teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles'], IDs: [np.int64(627638), np.int64(526064), np.int64(624443), np.int64(619892), np.int64(609179), np.int64(603182), np.int64(614043), np.int64(492744), np.int64(626849), np.int64(385307), np.int64(625818), np.int64(543739), np.int64(742226), np.int64(632228), np.int64(494103), np.int64(606857), np.int64(604897), np.int64(603612), np.int64(312320), np.int64(745297), np.int64(407257), np.int64(603838), np.int64(617542), np.int64(387522), np.int64(627252), np.int64(605207), np.int64(629263), np.int64(502722), np.int64(520828), np.int64(524441), np.int64(629025), np.int64(601094), np.int64(289440), np.int64(395712), np.int64(68949), np.int64(630948), np.int64(603007), np.int64(622023), np.int64(738379), np.int64(608688), np.int64(629221), np.int64(399605), np.int64(718026), np.int64(522345), np.int64(633143), np.int64(525420), np.int64(630098), np.int64(632684), np.int64(628744), np.int64(835124), np.int64(631600), np.int64(613776), np.int64(524485), np.int64(632320), np.int64(744091), np.int64(638838), np.int64(411253), np.int64(629156), np.int64(625319), np.int64(406863), np.int64(627169), np.int64(634455), np.int64(517064), np.int64(722431), np.int64(634328), np.int64(507448), np.int64(616449), np.int64(628986)]
# Group 24: Responses: ['do the right thing'], IDs: [np.int64(411117)]
# Group 25: Responses: ['jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sush', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi'], IDs: [np.int64(603182), np.int64(497421), np.int64(605452), np.int64(613209), np.int64(507448), np.int64(715814), np.int64(744484), np.int64(602871), np.int64(601950), np.int64(606150), np.int64(5978), np.int64(631881), np.int64(722500), np.int64(618747), np.int64(626771), np.int64(602657), np.int64(616568), np.int64(719735), np.int64(603933), np.int64(603838), np.int64(395712), np.int64(632189), np.int64(634669), np.int64(635533), np.int64(630389), np.int64(628990), np.int64(604386), np.int64(603664), np.int64(738379), np.int64(630098), np.int64(603388), np.int64(629142), np.int64(715806), np.int64(629156), np.int64(630250), np.int64(631531)]
# Group 26: Responses: ['chandni chowk to china'], IDs: [np.int64(606010)]
# Group 27: Responses: ['one piece film gold', 'one piece'], IDs: [np.int64(386750), np.int64(229211)]
# Group 28: Responses: ['memoirs of a geisha', 'memoirs of a geisha', 'memory of a geisha', 'memoirs of a geisha', 'memoirs of a geisha'], IDs: [np.int64(603607), np.int64(712252), np.int64(712771), np.int64(613409), np.int64(13183)]
# Group 29: Responses: ['high school musical 3', 'high school musical'], IDs: [np.int64(521125), np.int64(609257)]
# Group 30: Responses: ['spiderman no way home', 'spider man spider verse', 'spiderman across the spiderverse', 'spiderman into the spiderverse', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman'], IDs: [np.int64(724326), np.int64(632189), np.int64(743623), np.int64(630962), np.int64(602526), np.int64(634964), np.int64(631716), np.int64(622787), np.int64(630929), np.int64(631142), np.int64(518733), np.int64(411681), np.int64(633712), np.int64(631902), np.int64(206744), np.int64(716766), np.int64(523461), np.int64(504548), np.int64(634977), np.int64(209691), np.int64(634650), np.int64(410380), np.int64(524890), np.int64(631014), np.int64(408898), np.int64(522967), np.int64(627792), np.int64(407221), np.int64(491374), np.int64(630070), np.int64(97339), np.int64(723931), np.int64(631496), np.int64(632909), np.int64(617462), np.int64(525853), np.int64(507382), np.int64(313577), np.int64(522205), np.int64(413570), np.int64(743488), np.int64(495424), np.int64(411781), np.int64(393424), np.int64(714430), np.int64(602845), np.int64(714430), np.int64(726962), np.int64(496344), np.int64(630389), np.int64(607944), np.int64(626479), np.int64(604770), np.int64(525422), np.int64(409940), np.int64(602871), np.int64(608062), np.int64(719735), np.int64(632189), np.int64(626757), np.int64(631678), np.int64(744468), np.int64(519548), np.int64(601609)]
# Group 31: Responses: ['the end of evangelion'], IDs: [np.int64(605278)]
# Group 32: Responses: ['five nights at freddys', 'five nights at freddys', 'five nights at freddys', 'five nights at freddys', 'five nights at freddys'], IDs: [np.int64(630962), np.int64(408630), np.int64(611188), np.int64(738850), np.int64(628093)]
# Group 33: Responses: ['a silent voice 2016', 'a silent voice'], IDs: [np.int64(502722), np.int64(743623)]
# Group 34: Responses: ['who am i 2005'], IDs: [np.int64(387820)]
# Group 35: Responses: ['japanese movies food documentaries', 'japanese movies', 'japanese movie', 'japanese movie', 'japanese movie', 'japanese movie', 'japanese', 'japanese', 'japanese', 'japanese', 'japanese', 'japanese', 'japanese', 'japanese', 'japanese', 'japanese', 'japanese'], IDs: [np.int64(742611), np.int64(715742), np.int64(24137), np.int64(206487), np.int64(717411), np.int64(630117), np.int64(413014), np.int64(629878), np.int64(715152), np.int64(712670), np.int64(524803), np.int64(602560), np.int64(492744), np.int64(505458), np.int64(498213), np.int64(312320), np.int64(630190)]
# Group 36: Responses: ['batman the dark knight'], IDs: [np.int64(608062)]
# Group 37: Responses: ['the spy next door'], IDs: [np.int64(401586)]
# Group 38: Responses: ['the road to fallujah'], IDs: [np.int64(603582)]
# Group 39: Responses: ['scary movie 4 2006', 'scary movie'], IDs: [np.int64(627599), np.int64(629285)]
# Group 40: Responses: ['yeh jawaani hai deewani'], IDs: [np.int64(387820)]
# Group 41: Responses: ['this is the end'], IDs: [np.int64(523128)]
# Group 42: Responses: ['pirates of the caribbean', 'pirates of the caribbean', 'pirates of the carribeans'], IDs: [np.int64(629985), np.int64(522877), np.int64(714607)]
# Group 43: Responses: ['the prince of egypt'], IDs: [np.int64(631014)]
# Group 44: Responses: ['lord of the rings', 'lord of the rings'], IDs: [np.int64(606552), np.int64(630949)]
# Group 45: Responses: ['khabi khushi khabi gham'], IDs: [np.int64(631012)]
# Group 46: Responses: ['30 minutes or less'], IDs: [np.int64(517019)]
# Group 47: Responses: ['wolf of wall street', 'wolf of wallstreet'], IDs: [np.int64(601945), np.int64(622023)]
# Group 48: Responses: ['futurama benders big score'], IDs: [np.int64(631583)]
# Group 49: Responses: ['fast furious tokyo drift', 'fast and furious', 'fast and furious', 'fast and furious', 'fast and furious', 'fast and furious', 'fast and furious', 'fast and furious', 'fast and furious', 'fast and furious', 'fast and furious', 'fast and furious', 'fast and furious', 'fast and furious', 'fast and furious', 'fast and furious', 'fast furious', 'fast furious'], IDs: [np.int64(628102), np.int64(411810), np.int64(609556), np.int64(66222), np.int64(313562), np.int64(313562), np.int64(626757), np.int64(411253), np.int64(502610), np.int64(616568), np.int64(718026), np.int64(634430), np.int64(609179), np.int64(313562), np.int64(66222), np.int64(631046), np.int64(601609), np.int64(501893)]
# Group 50: Responses: ['ferris buellers day off'], IDs: [np.int64(631678)]
# Group 51: Responses: ['crayon shinchan the movie', 'crayon shinchan'], IDs: [np.int64(601941), np.int64(387522)]
# Group 52: Responses: ['pengnuins of madagascar', 'penguins of madagascar', 'penguins of madagascar'], IDs: [np.int64(631600), np.int64(635065), np.int64(631716)]
# Group 53: Responses: ['the big sick', 'the big lebowski', 'the big lebowski', 'the big short', 'the big short', 'the big short'], IDs: [np.int64(626482), np.int64(602805), np.int64(609116), np.int64(716650), np.int64(295428), np.int64(313577)]
# Group 54: Responses: ['the social network', 'the social network'], IDs: [np.int64(617774), np.int64(630967)]
# Group 55: Responses: ['the kite runner', 'the kite runner', 'the kite runner', 'the intern'], IDs: [np.int64(606726), np.int64(525567), np.int64(607410), np.int64(630823)]
# Group 56: Responses: ['legend of shawama'], IDs: [np.int64(723968)]
# Group 57: Responses: ['howls moving castle', 'howls moving castle', 'howls moving castle', 'howls moving castle'], IDs: [np.int64(635024), np.int64(712898), np.int64(742226), np.int64(626883)]
# Group 58: Responses: ['crazy rich asians', 'crazy rich asians', 'crazy rich asians', 'crazy rich asians', 'crazy rich asians', 'crazy rich asians', 'crazy rich asians', 'crazy rich asians'], IDs: [np.int64(508156), np.int64(606726), np.int64(738875), np.int64(497695), np.int64(525567), np.int64(630006), np.int64(524992), np.int64(607410)]
# Group 59: Responses: ['good will hunting'], IDs: [np.int64(603812)]
# Group 60: Responses: ['the avengers 1', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avenger', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the hangover', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the whale', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the hangover', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the hangover', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avenger ...
# Group 61: Responses: ['the barbie movie', 'the dora movie', 'the lego movie', 'the emoji movie', 'the goofy movie'], IDs: [np.int64(638838), np.int64(518733), np.int64(616634), np.int64(633520), np.int64(629792)]
# Group 62: Responses: ['any american movie', 'anime i guess', 'anime movie', 'anime', 'anime', 'anime', 'anime', 'anime'], IDs: [np.int64(602824), np.int64(604062), np.int64(607073), np.int64(522890), np.int64(625326), np.int64(405521), np.int64(604132), np.int64(716188)]
# Group 63: Responses: ['life of pi', 'life if pi'], IDs: [np.int64(715795), np.int64(628990)]
# Group 64: Responses: ['middle east movie', 'middle east movie', 'middle east movie', 'middle eastern movie', 'middle east movie', 'middle eastern movies', 'middle east movie'], IDs: [np.int64(742611), np.int64(24137), np.int64(606010), np.int64(601547), np.int64(498213), np.int64(716188), np.int64(409930)]
# Group 65: Responses: ['pursuit of happyness'], IDs: [np.int64(306207)]
# Group 66: Responses: ['big hero 6', 'big hero 6', 'big hero 6', 'big hero 6', 'big hero 6', 'big hero 6'], IDs: [np.int64(419835), np.int64(628077), np.int64(625818), np.int64(629221), np.int64(638838), np.int64(629700)]
# Group 67: Responses: ['my neighbor totoro', 'my neighbor totoro', 'my neighbor totoro', 'my neighbour totoro'], IDs: [np.int64(68949), np.int64(629041), np.int64(525420), np.int64(612478)]
# Group 68: Responses: ['isle of dogs', 'isle of dogs', 'isle of dogs', 'isle of dogs', 'isle of dogs', 'isle of dogs', 'isle of dogs', 'isle of dogs', 'isle of dogs'], IDs: [np.int64(616457), np.int64(626479), np.int64(628558), np.int64(617542), np.int64(606119), np.int64(520828), np.int64(627792), np.int64(616449), np.int64(633712)]
# Group 69: Responses: ['kung fu panda', 'kung fu panda', 'kung fu panda', 'kung fu panda', 'kung fu panda', 'kung fu panda', 'kung fu panda', 'kung fu panda', 'kung fu panda', 'kung fu panda', 'kung fu panda', 'kung fu panda', 'kungfu panda'], IDs: [np.int64(633224), np.int64(229041), np.int64(406863), np.int64(600915), np.int64(517064), np.int64(626482), np.int64(635627), np.int64(631012), np.int64(633097), np.int64(616836), np.int64(626792), np.int64(617379), np.int64(728522)]
# Group 70: Responses: ['black hawk down', 'black hawk down'], IDs: [np.int64(601950), np.int64(602824)]
# Group 71: Responses: ['the breakfast club', 'the breakfast club', 'the breakfast club', 'the breakfast club'], IDs: [np.int64(625315), np.int64(409723), np.int64(714893), np.int64(629615)]
# Group 72: Responses: ['sonic the hedgehog'], IDs: [np.int64(631711)]
# Group 73: Responses: ['lost in translation', 'lost in translation', 'lost in translation', 'lost in translation', 'lost in translation'], IDs: [np.int64(717116), np.int64(289440), np.int64(603189), np.int64(614089), np.int64(621982)]
# Group 74: Responses: ['the invisible guest'], IDs: [np.int64(620148)]
# Group 75: Responses: ['21 jump street', '21 jump street', '21 jump street'], IDs: [np.int64(631716), np.int64(193195), np.int64(602482)]
# Group 76: Responses: ['the last samurai', 'the last samurai', 'the last samurai', 'the samurai', '7 samurai'], IDs: [np.int64(627539), np.int64(631014), np.int64(522967), np.int64(603007), np.int64(626026)]
# Group 77: Responses: ['train to busan'], IDs: [np.int64(633097)]
# Group 78: Responses: ['rush hour 3', 'rush hour series', 'rush hour 2', 'rush hour 2', 'rush hour 2', 'rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour'], IDs: [np.int64(387330), np.int64(312640), np.int64(393424), np.int64(523461), np.int64(631909), np.int64(600849), np.int64(627539), np.int64(616945), np.int64(502799), np.int64(602533), np.int64(629807), np.int64(629072), np.int64(631181), np.int64(606905), np.int64(414710), np.int64(635627), np.int64(746466), np.int64(854745), np.int64(407257), np.int64(627505), np.int64(630738), np.int64(629263), np.int64(630378)]
# Group 79: Responses: ['saving private ryan'], IDs: [np.int64(519570)]
# Group 80: Responses: ['eat pray love', 'eat pray love', 'eat pray love'], IDs: [np.int64(498848), np.int64(508156), np.int64(603398)]
# Group 81: Responses: ['kodoku no gurume', 'kodoku no gurume'], IDs: [np.int64(716766), np.int64(630928)]
# Group 82: Responses: ['the italian job', 'the italian job', 'the italian job', 'the italian job', 'the italian job'], IDs: [np.int64(716188), np.int64(616713), np.int64(717411), np.int64(626771), np.int64(617310)]
# Group 83: Responses: ['life is beautiful'], IDs: [np.int64(606726)]
# Group 84: Responses: ['set it up', 'set it up'], IDs: [np.int64(526497), np.int64(835223)]
# Group 85: Responses: ['koe no katachi'], IDs: [np.int64(627530)]
# Group 86: Responses: ['james bond 007', 'james bond'], IDs: [np.int64(635533), np.int64(714062)]
# Group 87: Responses: ['the dark knight', 'the dark knight'], IDs: [np.int64(633541), np.int64(519681)]
# Group 88: Responses: ['lawrence of arabia', 'lawrence of arabia'], IDs: [np.int64(601737), np.int64(631583)]
# Group 89: Responses: ['recep ivedik 2', 'recep ivedik 2'], IDs: [np.int64(607517), np.int64(607517)]
# Group 90: Responses: ['the little mermaid'], IDs: [np.int64(609278)]
# Group 91: Responses: ['big big wolf'], IDs: [np.int64(526131)]
# Group 92: Responses: ['crazy stupid love', 'crazy stupid love'], IDs: [np.int64(411781), np.int64(519986)]
# Group 93: Responses: ['the meg 2018'], IDs: [np.int64(504548)]
# Group 94: Responses: ['deadpool and wolverine', 'deadpool', 'deadpool', 'deadpool', 'deadpool', 'deadpool', 'deadpool', 'deadpool', 'deadpool', 'deadpool', 'deadpool', 'deadpool', 'deadpool', 'deadpool', 'deadpool'], IDs: [np.int64(603130), np.int64(629710), np.int64(602394), np.int64(628093), np.int64(606150), np.int64(747734), np.int64(634430), np.int64(630006), np.int64(632868), np.int64(622787), np.int64(738875), np.int64(601945), np.int64(627599), np.int64(411315), np.int64(630250)]
# Group 95: Responses: ['spy kids 3d'], IDs: [np.int64(627636)]
# Group 96: Responses: ['harold and kumar'], IDs: [np.int64(712093)]
# Group 97: Responses: ['prince of egypt'], IDs: [np.int64(627427)]
# Group 98: Responses: ['karate kid ii', 'karate kid', 'karate kid', 'karate kid', 'karate kid', 'karate kid'], IDs: [np.int64(630070), np.int64(617310), np.int64(505318), np.int64(745297), np.int64(727410), np.int64(632228)]
# Group 99: Responses: ['spirited away 2001', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirit away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away'], IDs: [np.int64(631507), np.int64(630929), np.int64(520090), np.int64(716549), np.int64(602526), np.int64(715845), np.int64(519548), np.int64(713423), np.int64(411315), np.int64(628559), np.int64(625295), np.int64(603415), np.int64(517019), np.int64(409940), np.int64(399605), np.int64(712938), np.int64(601094), np.int64(712702), np.int64(611188), np.int64(631164), np.int64(517774), np.int64(524480), np.int64(634885), np.int64(526064)]
# Group 100: Responses: ['your name 2016', 'your name', 'your name', 'your name', 'your name', 'your name', 'your name', 'your name', 'your name', 'your name', 'your name', 'your name', 'your name', 'your name', 'your name', 'your name', 'your name'], IDs: [np.int64(743537), np.int64(630227), np.int64(620148), np.int64(609116), np.int64(607815), np.int64(631198), np.int64(632896), np.int64(612567), np.int64(633350), np.int64(631221), np.int64(209691), np.int64(632320), np.int64(634825), np.int64(746466), np.int64(631142), np.int64(625319), np.int64(741592)]
# Group 101: Responses: ['back in action'], IDs: [np.int64(603189)]
# Group 102: Responses: ['john wick 4', 'john wick', 'john wick', 'john wick', 'john wick', 'john wick', 'john wick', 'john wick', 'john wick', 'john wick', 'john wick', 'john wick', 'john wick', 'john wick', 'john wick', 'john wick'], IDs: [np.int64(601848), np.int64(630128), np.int64(633224), np.int64(632909), np.int64(634964), np.int64(618700), np.int64(613776), np.int64(635179), np.int64(721831), np.int64(310438), np.int64(410380), np.int64(385307), np.int64(503957), np.int64(206744), np.int64(523128), np.int64(611932)]
# Group 103: Responses: ['the karate kid', 'the karate kid', 'the karate kid'], IDs: [np.int64(607065), np.int64(634508), np.int64(627220)]
# Group 104: Responses: ['the lion king'], IDs: [np.int64(634566)]
# Group 105: Responses: ['the hunger games'], IDs: [np.int64(626883)]
# Group 106: Responses: ['the davinci code'], IDs: [np.int64(746466)]
# Group 107: Responses: ['weathering with you', 'weathering with you'], IDs: [np.int64(629758), np.int64(618355)]
# Group 108: Responses: ['billions tv show'], IDs: [np.int64(616713)]
# Group 109: Responses: ['the perfect storm'], IDs: [np.int64(715795)]
# Group 110: Responses: ['the truman show', 'the truman show'], IDs: [np.int64(603933), np.int64(609789)]
# Group 111: Responses: ['men in black', 'men in black', 'men in black'], IDs: [np.int64(387820), np.int64(621982), np.int64(629285)]
# Group 112: Responses: ['kingdom of heaven'], IDs: [np.int64(298481)]
# Group 113: Responses: ['my hero academia'], IDs: [np.int64(738409)]
# Group 114: Responses: ['any bollywood movie'], IDs: [np.int64(715152)]
# Group 115: Responses: ['captain of america', 'captain america'], IDs: [np.int64(726962), np.int64(628986)]
# Group 116: Responses: ['son of babylon'], IDs: [np.int64(635533)]
# Group 117: Responses: ['east side sushi'], IDs: [np.int64(622727)]
# Group 118: Responses: ['my cousin vinny'], IDs: [np.int64(626493)]
# Group 119: Responses: ['time of happiness'], IDs: [np.int64(629758)]
# Group 120: Responses: ['the princess diaries'], IDs: [np.int64(617178)]
# Group 121: Responses: ['rick and morty'], IDs: [np.int64(609789)]
# Group 122: Responses: ['la la land'], IDs: [np.int64(387155)]
# Group 123: Responses: ['kikis delivery service'], IDs: [np.int64(630209)]
# Group 124: Responses: ['action movie', 'action movie'], IDs: [np.int64(727333), np.int64(727333)]
# Group 125: Responses: ['mamma mia'], IDs: [np.int64(606874)]
# Group 126: Responses: ['food wars', 'food wars', 'food wars', 'food wars'], IDs: [np.int64(617178), np.int64(612096), np.int64(604897), np.int64(617178)]
# Group 127: Responses: ['kill bill', 'kill bill', 'kill bill', 'kill bill', 'kill bill', 'kill bill', 'kill bill', 'kill bill', 'kill bill', 'kill bill', 'kill bill', 'kill bill', 'kill bill', 'kill bill'], IDs: [np.int64(495424), np.int64(716142), np.int64(389328), np.int64(611097), np.int64(607160), np.int64(498848), np.int64(87783), np.int64(228777), np.int64(629010), np.int64(193195), np.int64(603812), np.int64(711854), np.int64(624443), np.int64(529289)]
# Group 128: Responses: ['midnight dinner', 'midnight diner', 'midnight diner'], IDs: [np.int64(501513), np.int64(388888), np.int64(630044)]
# Group 129: Responses: ['mystic pizza', 'mystic pizza', 'mystic pizza'], IDs: [np.int64(388888), np.int64(601693), np.int64(603607)]
# Group 130: Responses: ['the dictator', 'the dictator', 'the dictator', 'the dictator', 'the dictator', 'the dictator', 'the dictator', 'the dictator', 'the dictator', 'the dictator', 'the dictator', 'the dictator', 'the dictator', 'the dictator'], IDs: [np.int64(625319), np.int64(524803), np.int64(627505), np.int64(606874), np.int64(632228), np.int64(630967), np.int64(606857), np.int64(603007), np.int64(630972), np.int64(387330), np.int64(632051), np.int64(718026), np.int64(524992), np.int64(629700)]
# Group 131: Responses: ['indiana jones', 'indian movie'], IDs: [np.int64(723931), np.int64(717411)]
# Group 132: Responses: ['bad boys'], IDs: [np.int64(721831)]
# Group 133: Responses: ['3 idiots', '3 idiots', '3 idiots'], IDs: [np.int64(712938), np.int64(408630), np.int64(501513)]
# Group 134: Responses: ['monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monster house', 'monsters inc', 'monster inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monster house', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monster'], IDs: [np.int64(605148), np.int64(634646), np.int64(633001), np.int64(634690), np.int64(631125), np.int64(407221), np.int64(602394), np.int64(627252), np.int64(627636), np.int64(629792), np.int64(389109), np.int64(604110), np.int64(523710), np.int64(543739), np.int64(635024), np.int64(632975), np.int64(631141), np.int64(631069), np.int64(604991), np.int64(411117), np.int64(628547), np.int64(620745), np.int64(635602), np.int64(619892), np.int64(712143)]
# Group 135: Responses: ['shawarma bowl', 'shawarma legend', 'shawarma legend', 'shawarma legend', 'shawarma legend'], IDs: [np.int64(712702), np.int64(601941), np.int64(712143), np.int64(713423), np.int64(501893)]
# Group 136: Responses: ['47 ronin', '47 ronin'], IDs: [np.int64(507382), np.int64(606857)]
# Group 137: Responses: ['barbie 2021', 'barbie', 'barbie', 'barbie'], IDs: [np.int64(522877), np.int64(632975), np.int64(627488), np.int64(519638)]
# Group 138: Responses: ['the mummy', 'the mummy', 'the menu'], IDs: [np.int64(611188), np.int64(605519), np.int64(743488)]
# Group 139: Responses: ['forest gump'], IDs: [np.int64(613409)]
# Group 140: Responses: ['cartoon movie', 'cartoons'], IDs: [np.int64(727333), np.int64(498213)]
# Group 141: Responses: ['johnny english', 'johnny english', 'johnny english', 'johnny english'], IDs: [np.int64(606874), np.int64(631583), np.int64(629710), np.int64(608318)]
# Group 142: Responses: ['star wars', 'star wars', 'star wars', 'star wars', 'star wars', 'star wars', 'star wars'], IDs: [np.int64(630949), np.int64(228777), np.int64(712054), np.int64(724326), np.int64(608554), np.int64(626883), np.int64(612567)]
# Group 143: Responses: ['fight club', 'fight club'], IDs: [np.int64(740568), np.int64(504599)]
# Group 144: Responses: ['bullet train', 'bullet train', 'bullet train', 'bullet train', 'bullet train', 'bullet train', 'bullet train'], IDs: [np.int64(626754), np.int64(627780), np.int64(607609), np.int64(605207), np.int64(714901), np.int64(496344), np.int64(494373)]
# Group 145: Responses: ['shark tale', 'shark tale', 'shark tale', 'shark tale'], IDs: [np.int64(521125), np.int64(413570), np.int64(601693), np.int64(631902)]
# Group 146: Responses: ['lion king', 'lion king'], IDs: [np.int64(406863), np.int64(631909)]
# Group 147: Responses: ['gi joe'], IDs: [np.int64(617029)]
# Group 148: Responses: ['finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo'], IDs: [np.int64(289931), np.int64(632153), np.int64(634328), np.int64(628744), np.int64(608704), np.int64(605519), np.int64(408630), np.int64(520037), np.int64(524441), np.int64(632868), np.int64(524485), np.int64(743828), np.int64(630972), np.int64(630948), np.int64(390823), np.int64(720045), np.int64(625576), np.int64(603130), np.int64(603612), np.int64(627798), np.int64(525853)]
# Group 149: Responses: ['jurassic park'], IDs: [np.int64(609257)]
# Group 150: Responses: ['meitantei konan'], IDs: [np.int64(504599)]
# Group 151: Responses: ['pulp fiction', 'pulp fiction', 'pulp fiction'], IDs: [np.int64(627636), np.int64(229211), np.int64(606119)]
# Group 152: Responses: ['squid game', 'squid game', 'squid game', 'squid game'], IDs: [np.int64(295428), np.int64(629025), np.int64(387155), np.int64(295428)]
# Group 153: Responses: ['cars 2', 'cars 2', 'cars 2', 'cars 2', 'cars 2', 'cars 2', 'cars 2', 'cars 2', 'cars 3', 'cars', 'cars', 'cars', 'cars', 'cars', 'cars', 'cars'], IDs: [np.int64(714598), np.int64(634468), np.int64(626493), np.int64(628093), np.int64(626778), np.int64(612538), np.int64(408898), np.int64(604969), np.int64(718089), np.int64(628736), np.int64(600915), np.int64(740568), np.int64(522205), np.int64(614043), np.int64(632684), np.int64(617774)]
# Group 154: Responses: ['harry potter', 'harry potter', 'harry potter', 'harry potter', 'harry poter', 'harry potter', 'harry potter'], IDs: [np.int64(601609), np.int64(496858), np.int64(634646), np.int64(712054), np.int64(624540), np.int64(523080), np.int64(516975)]
# Group 155: Responses: ['gone girl'], IDs: [np.int64(606552)]
# Group 156: Responses: ['the pacific'], IDs: [np.int64(602824)]
# Group 157: Responses: ['the proposal', 'the room'], IDs: [np.int64(600957), np.int64(629985)]
# Group 158: Responses: ['rurouni kenshin'], IDs: [np.int64(722431)]
# Group 159: Responses: ['iron man', 'iron man', 'iron man', 'iron man'], IDs: [np.int64(628559), np.int64(630823), np.int64(714430), np.int64(607410)]
# Group 160: Responses: ['comedy movie', 'comedy', 'comedy'], IDs: [np.int64(840827), np.int64(24137), np.int64(389697)]
# Group 161: Responses: ['seven samurai'], IDs: [np.int64(712093)]
# Group 162: Responses: ['house md'], IDs: [np.int64(519570)]
# Group 163: Responses: ['madagascar 2', 'madagascar', 'madagascar', 'madagascar', 'madagascar', 'madagascar', 'madagascar', 'madagascar'], IDs: [np.int64(522345), np.int64(520861), np.int64(519822), np.int64(632299), np.int64(634650), np.int64(522477), np.int64(622787), np.int64(625349)]
# Group 164: Responses: ['ip man'], IDs: [np.int64(204508)]
# Group 165: Responses: ['ghibli movies'], IDs: [np.int64(389697)]
# Group 166: Responses: ['gossip girl'], IDs: [np.int64(627488)]
# Group 167: Responses: ['taxi driver', 'taxi driver'], IDs: [np.int64(629712), np.int64(633541)]
# Group 168: Responses: ['romance movie', 'romantic movies'], IDs: [np.int64(840827), np.int64(413395)]
# Group 169: Responses: ['django unchained'], IDs: [np.int64(601983)]
# Group 170: Responses: ['monty python'], IDs: [np.int64(601363)]
# Group 171: Responses: ['pacific rim'], IDs: [np.int64(629959)]
# Group 172: Responses: ['love hard'], IDs: [np.int64(605290)]
# Group 173: Responses: ['the boys'], IDs: [np.int64(625326)]
# Group 174: Responses: ['gran turismo'], IDs: [np.int64(617774)]
# Group 175: Responses: ['samurai jack'], IDs: [np.int64(629844)]
# Group 176: Responses: ['mean girls', 'mean girls'], IDs: [np.int64(609257), np.int64(605290)]
# Group 177: Responses: ['girls trip'], IDs: [np.int64(717921)]
# Group 178: Responses: ['the godfather', 'the godfather', 'the godfather', 'the godfather', 'the godfather', 'the godfather', 'the godfather', 'the godfather', 'the godfather', 'the godfather', 'the godfather', 'the godfather'], IDs: [np.int64(630949), np.int64(747734), np.int64(720045), np.int64(626482), np.int64(618700), np.int64(601217), np.int64(520303), np.int64(614089), np.int64(603130), np.int64(630190), np.int64(631046), np.int64(607815)]
# Group 179: Responses: ['slumdog millionaire', 'slumdog millionaire'], IDs: [np.int64(529289), np.int64(502799)]
# Group 180: Responses: ['anjaana anjaani'], IDs: [np.int64(626792)]
# Group 181: Responses: ['1001 nights'], IDs: [np.int64(627780)]
# Group 182: Responses: ['fallen angels'], IDs: [np.int64(523128)]
# Group 183: Responses: ['home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone'], IDs: [np.int64(746750), np.int64(629285), np.int64(517096), np.int64(602394), np.int64(87783), np.int64(744484), np.int64(523710), np.int64(522890), np.int64(409723), np.int64(310438), np.int64(627430), np.int64(603812), np.int64(634690), np.int64(613209), np.int64(498563), np.int64(211158), np.int64(605148), np.int64(716142), np.int64(633224), np.int64(229041), np.int64(523080), np.int64(629041), np.int64(626779), np.int64(611716), np.int64(714893), np.int64(618150), np.int64(524890), np.int64(631881), np.int64(626754), np.int64(603415), np.int64(626778), np.int64(632051), np.int64(625315), np.int64(721831), np.int64(632868), np.int64(601983), np.int64(630006), np.int64(625295), np.int64(716650), np.int64(496858), np.int64(604110), np.int64(712766), np.int64(738875), np.int64(630121), np.int64(739254), np.int64(503957), np.int64(608704), np.int64(603793), np.int64(601122), np.int64(631125), np.int64(520037), np.int64(630378), np.int64(601986), np.int64(631141), np.int64(631069), np.int64(627496), np.int64(401586), np.int64(604826), np.int64(605519), np.int64(741592), np.int64(611932), np.int64(622727), np.int64(522148), np.int64(612131), np.int64(600957), np.int64(632896), np.int64(722500), np.int64(611097), np.int64(644623)]
# Group 184: Responses: ['detective conan'], IDs: [np.int64(726962)]
# Group 185: Responses: ['grown ups', 'grown ups', 'grown ups'], IDs: [np.int64(618333), np.int64(634508), np.int64(612478)]
# Group 186: Responses: ['shanghai noon', 'shang chi', 'shangchi'], IDs: [np.int64(634566), np.int64(518733), np.int64(632893)]
# Group 187: Responses: ['green book', 'green book', 'green book', 'green book'], IDs: [np.int64(631198), np.int64(712938), np.int64(712771), np.int64(712054)]
# Group 188: Responses: ['little italy', 'little italy', 'little italy', 'little italy'], IDs: [np.int64(606150), np.int64(712143), np.int64(740568), np.int64(630128)]
# Group 189: Responses: ['murder mystery'], IDs: [np.int64(607286)]
# Group 190: Responses: ['liquorice pizza'], IDs: [np.int64(625576)]
# Group 191: Responses: ['toy story', 'toy story', 'toy story', 'toy story', 'toy story', 'toy story', 'toy story', 'toy story'], IDs: [np.int64(612538), np.int64(411810), np.int64(600915), np.int64(604991), np.int64(629659), np.int64(718089), np.int64(628736), np.int64(618747)]
# Group 192: Responses: ['mario movie', 'mario movie', 'mario movie'], IDs: [np.int64(627539), np.int64(743828), np.int64(634705)]
# Group 193: Responses: ['uncle grandpa'], IDs: [np.int64(605452)]
# Group 194: Responses: ['mr deeds'], IDs: [np.int64(5978)]
# Group 195: Responses: ['turning red', 'turning red', 'turning red'], IDs: [np.int64(626849), np.int64(632125), np.int64(631711)]
# Group 196: Responses: ['taken 2'], IDs: [np.int64(401586)]
# Group 197: Responses: ['chinese zodiac'], IDs: [np.int64(613484)]
# Group 198: Responses: ['the ritual'], IDs: [np.int64(630198)]
# Group 199: Responses: ['the grinch', 'the grinch'], IDs: [np.int64(634764), np.int64(629985)]
# Group 200: Responses: ['the wicked'], IDs: [np.int64(613409)]
# Group 201: Responses: ['free guy'], IDs: [np.int64(627530)]
# Group 202: Responses: ['shawshank redemption'], IDs: [np.int64(634885)]
# Group 203: Responses: ['mad max'], IDs: [np.int64(601986)]
# Group 204: Responses: ['relaxing comedy'], IDs: [np.int64(714503)]
# Group 205: Responses: ['blade runner', 'bladerunner', 'bladerunner'], IDs: [np.int64(494103), np.int64(611716), np.int64(744468)]
# Group 206: Responses: ['cheech chong'], IDs: [np.int64(312320)]
# Group 207: Responses: ['american pie'], IDs: [np.int64(633097)]
# Group 208: Responses: ['running man'], IDs: [np.int64(228777)]
# Group 209: Responses: ['good time'], IDs: [np.int64(604826)]
# Group 210: Responses: ['last samurai'], IDs: [np.int64(601737)]
# Group 211: Responses: ['the gentlemen'], IDs: [np.int64(634566)]
# Group 212: Responses: ['gilmore girls'], IDs: [np.int64(631109)]
# Group 213: Responses: ['maze runner'], IDs: [np.int64(524480)]
# Group 214: Responses: ['happy gilmore'], IDs: [np.int64(628102)]
# Group 215: Responses: ['die hard'], IDs: [np.int64(525311)]
# Group 216: Responses: ['neverending story'], IDs: [np.int64(604969)]
# Group 217: Responses: ['ultraman rising'], IDs: [np.int64(739254)]
# Group 218: Responses: ['pearl harbour'], IDs: [np.int64(296589)]
# Group 219: Responses: ['city hunter'], IDs: [np.int64(727339)]
# Group 220: Responses: ['alitathe warrior'], IDs: [np.int64(601986)]
# Group 221: Responses: ['aladdin idk', 'aladdin', 'aladdin', 'aladdin', 'aladdin', 'aladdin', 'aladdin', 'aladdin', 'aladdin', 'aladdin', 'aladdin', 'aladdin', 'aladdin', 'aladdin', 'alladin', 'aladdin', 'alladin', 'aladdin', 'aladdin'], IDs: [np.int64(631164), np.int64(712670), np.int64(523710), np.int64(616836), np.int64(633520), np.int64(629072), np.int64(739254), np.int64(630121), np.int64(634508), np.int64(609556), np.int64(13183), np.int64(715806), np.int64(629041), np.int64(609278), np.int64(714607), np.int64(612096), np.int64(502610), np.int64(289931), np.int64(635065)]
# Group 222: Responses: ['scooby doo'], IDs: [np.int64(607065)]
# Group 223: Responses: ['waynes world'], IDs: [np.int64(629723)]
# Group 224: Responses: ['scific type'], IDs: [np.int64(607073)]
# Group 225: Responses: ['breakfast club'], IDs: [np.int64(519976)]
# Group 226: Responses: ['air bud'], IDs: [np.int64(627427)]
# Group 227: Responses: ['space jam'], IDs: [np.int64(520090)]
# Group 228: Responses: ['three idiots'], IDs: [np.int64(631181)]
# Group 229: Responses: ['13 hours'], IDs: [np.int64(634705)]
# Group 230: Responses: ['step brothers'], IDs: [np.int64(529289)]
# Group 231: Responses: ['horror movie'], IDs: [np.int64(601547)]
# Group 232: Responses: ['angry birds'], IDs: [np.int64(632893)]
# Group 233: Responses: ['inside out'], IDs: [np.int64(713423)]
# Group 234: Responses: ['stranger things'], IDs: [np.int64(738409)]
# Group 235: Responses: ['despicable me', 'despicable me'], IDs: [np.int64(627220), np.int64(627780)]
# Group 236: Responses: ['king kong'], IDs: [np.int64(618355)]
# Group 237: Responses: ['notting hill'], IDs: [np.int64(526497)]
# Group 238: Responses: ['dead silence'], IDs: [np.int64(620148)]
# Group 239: Responses: ['none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none'], IDs: [np.int64(714863), np.int64(630738), np.int64(524766), np.int64(601547), np.int64(718570), np.int64(148179), np.int64(501416), np.int64(627638), np.int64(630977), np.int64(632320), np.int64(746750), np.int64(616713), np.int64(626789), np.int64(634455), np.int64(5978), np.int64(518809), np.int64(633024), np.int64(741428), np.int64(491374), np.int64(517064), np.int64(386750), np.int64(524766), np.int64(522483), np.int64(605290), np.int64(630948), np.int64(626812), np.int64(632125), np.int64(505458), np.int64(630977), np.int64(621555), np.int64(634683), np.int64(626812), np.int64(626789), np.int64(633024), np.int64(741428), np.int64(505458), np.int64(602482), np.int64(630999), np.int64(630117), np.int64(631069), np.int64(619932), np.int64(632156), np.int64(518809), np.int64(520507), np.int64(630977), np.int64(522483), np.int64(519976), np.int64(627638), np.int64(526064), np.int64(607073), np.int64(414734), np.int64(455047), np.int64(611932), np.int64(630929), np.int64(317214), np.int64(500470), np.int64(713585), np.int64(603182), np.int64(630738), np.int64(526510), np.int64(631216), np.int64(746750), np.int64(618150), np.int64(835223), np.int64(626779), np.int64(716749), np.int64(181851), np.int64(500077), np.int64(520383), np.int64(634455), np.int64(317214), np.int64(618333), np.int64(525422), np.int64(148179), np.int64(501416), np.int64(719554), np.int64(514199), np.int64(632091), np.int64(714863), np.int64(644623), np.int64(520507), np.int64(718570), np.int64(713585), np.int64(211158), np.int64(414734), np.int64(518809), np.int64(526510), np.int64(605771), np.int64(455047), np.int64(835223), np.int64(626779), np.int64(520861), np.int64(716749), np.int64(181851), np.int64(630999), np.int64(625295), np.int64(628990), np.int64(605254), np.int64(632156), np.int64(626789), np.int64(618150), np.int64(632091), np.int64(500077), np.int64(526131), np.int64(520383), np.int64(719735), np.int64(616568), np.int64(632975), np.int64(409930), np.int64(491374), np.int64(602560), np.int64(629878), np.int64(501416), np.int64(719554), np.int64(617542), np.int64(633024), np.int64(741428), np.int64(627252), np.int64(389697), np.int64(514199), np.int64(718570), np.int64(405521), np.int64(738409), np.int64(148179), np.int64(609789), np.int64(605771), np.int64(715742), np.int64(455047), np.int64(714863), np.int64(715814), np.int64(716749), np.int64(181851), np.int64(626812), np.int64(713585), np.int64(526510), np.int64(605254), np.int64(601941), np.int64(621555), np.int64(632091), np.int64(520383), np.int64(719554), np.int64(522483), np.int64(514199), np.int64(414734), np.int64(605771), np.int64(741658), np.int64(520507), np.int64(630999), np.int64(714062), np.int64(630117), np.int64(631600), np.int64(211158), np.int64(411 ...
# Group 240: Responses: ['goodfellas', 'goodfellas', 'goodfellas'], IDs: [np.int64(389328), np.int64(519976), np.int64(616457)]
# Group 241: Responses: ['transformer', 'transformers', 'transformer', 'transformers', 'transformer', 'transformers'], IDs: [np.int64(630825), np.int64(631678), np.int64(630823), np.int64(632893), np.int64(630825), np.int64(389328)]
# Group 242: Responses: ['pokemon', 'pokemon', 'pokemon'], IDs: [np.int64(522148), np.int64(632431), np.int64(835124)]
# Group 243: Responses: ['ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatoullie', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille'], IDs: [np.int64(632117), np.int64(612096), np.int64(632153), np.int64(605537), np.int64(388729), np.int64(601848), np.int64(631012), np.int64(743623), np.int64(632117), np.int64(741658), np.int64(495424), np.int64(628547), np.int64(626026), np.int64(630044), np.int64(388729), np.int64(609556), np.int64(631711), np.int64(631448), np.int64(605537), np.int64(634683), np.int64(630416), np.int64(629959), np.int64(631164), np.int64(629807), np.int64(604132), np.int64(630416), np.int64(626026), np.int64(206487), np.int64(616836), np.int64(631448), np.int64(633001), np.int64(388729), np.int64(712670), np.int64(508149), np.int64(632431), np.int64(525567), np.int64(605537), np.int64(630250), np.int64(606905), np.int64(723968), np.int64(632117), np.int64(410165), np.int64(627169), np.int64(616945), np.int64(500470), np.int64(629844), np.int64(520861), np.int64(608318), np.int64(603664), np.int64(630416), np.int64(604386), np.int64(609278), np.int64(633350), np.int64(519986), np.int64(627488), np.int64(616945)]
# Group 244: Responses: ['pizza', 'pizza', 'pizza', 'pizza'], IDs: [np.int64(743537), np.int64(604062), np.int64(602560), np.int64(602657)]
# Group 245: Responses: ['superbad', 'superbad', 'superbad', 'superbad'], IDs: [np.int64(606552), np.int64(600849), np.int64(505318), np.int64(413014)]
# Group 246: Responses: ['whiplash'], IDs: [np.int64(603476)]
# Group 247: Responses: ['gladiator', 'gladiator'], IDs: [np.int64(635179), np.int64(497695)]
# Group 248: Responses: ['drishyam'], IDs: [np.int64(630928)]
# Group 249: Responses: ['coco'], IDs: [np.int64(601983)]
# Group 250: Responses: ['hangover'], IDs: [np.int64(631221)]
# Group 251: Responses: ['spongebob', 'spongebob'], IDs: [np.int64(630209), np.int64(617379)]
# Group 252: Responses: ['garfield', 'garfield', 'garfield', 'garfield', 'garfield', 'garfield', 'garfield', 'garfield'], IDs: [np.int64(66222), np.int64(414710), np.int64(603388), np.int64(712898), np.int64(601363), np.int64(606556), np.int64(601950), np.int64(714598)]
# Group 253: Responses: ['oppenheimer', 'oppenheimer', 'oppenheimer'], IDs: [np.int64(618333), np.int64(601217), np.int64(629659)]
# Group 254: Responses: ['borat', 'borat', 'borat', 'borat', 'borat', 'borat', 'borat', 'borat'], IDs: [np.int64(606905), np.int64(629221), np.int64(525420), np.int64(630190), np.int64(745297), np.int64(411315), np.int64(606119), np.int64(617029)]
# Group 255: Responses: ['chef', 'chef', 'chef', 'chef', 'chef'], IDs: [np.int64(635602), np.int64(602845), np.int64(619892), np.int64(607944), np.int64(631109)]
# Group 256: Responses: ['friends', 'friends'], IDs: [np.int64(501513), np.int64(854745)]
# Group 257: Responses: ['11sep'], IDs: [np.int64(601217)]
# Group 258: Responses: ['dune', 'dune', 'dune', 'dune'], IDs: [np.int64(629869), np.int64(625349), np.int64(519638), np.int64(612567)]
# Group 259: Responses: ['shrek', 'shrek', 'shrek', 'shrek3', 'shrek', 'shrek', 'shrek', 'shrek2'], IDs: [np.int64(602234), np.int64(214145), np.int64(602234), np.int64(214145), np.int64(526131), np.int64(602234), np.int64(522877), np.int64(214145)]
# Group 260: Responses: ['dangal', 'dangal', 'dangal', 'dangal'], IDs: [np.int64(716766), np.int64(606556), np.int64(607160), np.int64(715845)]
# Group 261: Responses: ['mulan', 'mulan', 'mulan', 'mulan'], IDs: [np.int64(631109), np.int64(634977), np.int64(630121), np.int64(631448)]
# Group 262: Responses: ['shazam'], IDs: [np.int64(745732)]
# Group 263: Responses: ['interstellar', 'interstellar', 'interstellar', 'interstellar', 'interstellar'], IDs: [np.int64(419835), np.int64(517774), np.int64(298481), np.int64(607609), np.int64(629712)]
# Group 264: Responses: ['terminator'], IDs: [np.int64(296589)]
# Group 265: Responses: ['luca', 'lucy'], IDs: [np.int64(634885), np.int64(634683)]
# Group 266: Responses: ['minions', 'minions'], IDs: [np.int64(602482), np.int64(629844)]
# Group 267: Responses: ['zootopia', 'zootopia'], IDs: [np.int64(711854), np.int64(717921)]
# Group 268: Responses: ['anchorman'], IDs: [np.int64(312640)]
# Group 269: Responses: ['malena'], IDs: [np.int64(522477)]
# Group 270: Responses: ['mandoob'], IDs: [np.int64(603189)]
# Group 271: Responses: ['friday'], IDs: [np.int64(629869)]
# Group 272: Responses: ['masterchef', 'masterchef'], IDs: [np.int64(523080), np.int64(738850)]
# Group 273: Responses: ['inception', 'inception', 'inception'], IDs: [np.int64(517774), np.int64(627505), np.int64(630198)]
# Group 274: Responses: ['dabba'], IDs: [np.int64(712771)]
# Group 275: Responses: ['godfather', 'godfather', 'godfather'], IDs: [np.int64(602533), np.int64(723968), np.int64(605278)]
# Group 276: Responses: ['breakaway'], IDs: [np.int64(635065)]
# Group 277: Responses: ['dictator', 'dictator'], IDs: [np.int64(718089), np.int64(618355)]
# Group 278: Responses: ['documentary', 'documenary'], IDs: [np.int64(742611), np.int64(714503)]
# Group 279: Responses: ['yakuza'], IDs: [np.int64(606821)]
# Group 280: Responses: ['snowpiercer'], IDs: [np.int64(517096)]
# Group 281: Responses: ['suzume'], IDs: [np.int64(627800)]
# Group 282: Responses: ['wolverine', 'wolverine', 'wolverine', 'wolverine', 'wolverine', 'wolverine', 'wolverine', 'wolverine'], IDs: [np.int64(627169), np.int64(612131), np.int64(712766), np.int64(744091), np.int64(601122), np.int64(602805), np.int64(97339), np.int64(616634)]
# Group 283: Responses: ['burnt'], IDs: [np.int64(386750)]
# Group 284: Responses: ['bollywood'], IDs: [np.int64(522148)]
# Group 285: Responses: ['ponyo', 'ponyo', 'ponyo'], IDs: [np.int64(627430), np.int64(747734), np.int64(607944)]
# Group 286: Responses: ['talented'], IDs: [np.int64(624540)]
# Group 287: Responses: ['passengers2016'], IDs: [np.int64(633143)]
# Group 288: Responses: ['parasite', 'parasite', 'parasite'], IDs: [np.int64(629712), np.int64(608062), np.int64(519681)]
# Group 289: Responses: ['doraemon', 'doraemon', 'doraemon'], IDs: [np.int64(603793), np.int64(606556), np.int64(854745)]
# Group 290: Responses: ['godzilla', 'godzilla', 'godzilla', 'godzilla', 'godzilla', 'godzilla', 'godzilla'], IDs: [np.int64(604770), np.int64(607286), np.int64(603582), np.int64(632051), np.int64(520303), np.int64(525311), np.int64(411681)]
# Group 291: Responses: ['oldboy', 'oldboy', 'oldboy'], IDs: [np.int64(633234), np.int64(603476), np.int64(617462)]
# Group 292: Responses: ['suits'], IDs: [np.int64(603398)]
# Group 293: Responses: ['frozen'], IDs: [np.int64(627798)]
# Group 294: Responses: ['jaws', 'jaws'], IDs: [np.int64(630962), np.int64(631436)]
# Group 295: Responses: ['naruto', 'naruto'], IDs: [np.int64(724326), np.int64(723931)]
# Group 296: Responses: ['aquaman', 'aquaman'], IDs: [np.int64(628986), np.int64(613484)]
# Group 297: Responses: ['drive'], IDs: [np.int64(519638)]
# Group 298: Responses: ['drange', 'dragon', 'dragon'], IDs: [np.int64(606929), np.int64(606929), np.int64(606929)]
# Group 299: Responses: ['bahen'], IDs: [np.int64(624540)]
# Group 300: Responses: ['arcane'], IDs: [np.int64(627530)]
# Group 301: Responses: ['wicked'], IDs: [np.int64(717921)]
# Group 302: Responses: ['wags'], IDs: [np.int64(498563)]
# Group 303: Responses: ['9'], IDs: [np.int64(634764)]
# Group 304: Responses: ['2012'], IDs: [np.int64(715795)]
# Group 305: Responses: ['shogun'], IDs: [np.int64(629869)]
# Group 306: Responses: ['casablanca'], IDs: [np.int64(633541)]
# Group 307: Responses: ['babylon'], IDs: [np.int64(633234)]
# Group 308: Responses: ['totoro', 'totoro'], IDs: [np.int64(727410), np.int64(619932)]
# Group 309: Responses: ['titanic'], IDs: [np.int64(630825)]
# Group 310: Responses: ['argo'], IDs: [np.int64(497421)]
# Group 311: Responses: ['hawkeye'], IDs: [np.int64(602526)]
# Group 312: Responses: ['cleopatra'], IDs: [np.int64(605278)]
# Group 313: Responses: ['soul'], IDs: [np.int64(715806)]
# Group 314: Responses: ['hitman'], IDs: [np.int64(627800)]
# Group 315: Responses: ['carryon'], IDs: [np.int64(634669)]
# Group 316: Responses: ['hunger'], IDs: [np.int64(630967)]
# Group 317: Responses: ['walle'], IDs: [np.int64(629878)]
# Group 318: Responses: ['coraline'], IDs: [np.int64(629010)]
# Group 319: Responses: ['moneyball'], IDs: [np.int64(497695)]
# Group 320: Responses: ['venom'], IDs: [np.int64(714607)]
# Group 321: Responses: ['heretic'], IDs: [np.int64(629723)]
# Group 322: Responses: ['haikyu'], IDs: [np.int64(627496)]
# Group 323: Responses: ['futurama'], IDs: [np.int64(405521)]
# Group 324: Responses: ['us'], IDs: [np.int64(630227)]
# Group 325: Responses: ['alien'], IDs: [np.int64(525853)]
# Group 326: Responses: ['nosferatu'], IDs: [np.int64(519822)]

# %%
# Output the DataFrame
print(clusters_df)
df_i = clusters_df

"""
# List of IDs to merge
ids_to_merge = [268, 23 271  98 290  14   ]


ids_to_merge_avengers = [66, 72, 158, ]
turtles = [  223,            ]

df_i = clusters_df

# Filter rows with the specified IDs
filtered_df = df_i[df_i['Cluster ID'].isin(ids_to_merge)]

print(filtered_df)

# Ensure 'Responses' and 'IDs' are lists (handle cases where they are strings)
def ensure_list(value):
    if isinstance(value, str):  # If it's a string, split it into a list
        return value.split(', ')
    return value  # Otherwise, assume it's already a list


# Aggregate the data
merged_row = {
    'Cluster ID': ids_to_merge[0],  # Use the first ID as the label
    'Responses': sum(filtered_df['Responses'].apply(ensure_list).tolist(), []),  # Concatenate lists of responses
    'IDs': sum(filtered_df['IDs'].apply(ensure_list).tolist(), []),  # Concatenate lists of IDs
    'Number of Responses': filtered_df['Number of Responses'].sum(),  # Sum the count
}

# Create a new DataFrame for the merged row
merged_df = pd.DataFrame([merged_row])

# Remove the merged rows from the original DataFrame
df_i = df_i[~df_i['Cluster ID'].isin(ids_to_merge)]
"""

def ensure_list(value):
    if isinstance(value, str):  # If it's a string, split it into a list
        return value.split(', ')
    return value  # Otherwise, assume it's already a list


# Function to find the median-length string in a list
def find_median_length_string(string_list):
    if not string_list:  # Handle empty lists
        return None
    # Sort the list by string length
    sorted_list = sorted(string_list, key=lambda x: len(x))
    # Find the median index
    median_index = len(sorted_list) // 2
    return sorted_list[median_index]  # Return the entire string

# Apply the function to the 'Responses' column to create the 'Label' column
df_i['Label'] = df_i['Responses'].apply(ensure_list).apply(find_median_length_string)
df_i.to_csv('/content/clusters_output_v2.csv', index=False)


# Iterate through each row in all_res_mapping
for index, row in df_i.iterrows():
    ids = row['IDs']  # Get the list of IDs for this group
    label = row['Label']  # Get the label for this group

    # Iterate through each ID in the list
    for id in ids:
        # Find the row in qq where the 'id' column matches the current ID
        match_index = model_df[model_df['id'] == id].index

        # If a match is found, replace the 'question' column with the label
        if not match_index.empty:
            model_df.loc[match_index, question] = label

model_df = model_df.fillna('none')

import pandas as pd
import copy
import ast

stopwords = [
    'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've",
    "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself',
    'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them',
    'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll",
    'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has',
    'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or',
    'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against',
    'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from',
    'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once',
    'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',
    'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
    'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now',
    'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn',
    "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn',
    "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't",
    'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"
]


# Function to remove stopwords from a text
def remove_stopwords(text):
    words = text.split()  # Split the text into words
    filtered_words = [word for word in words if word.lower() not in stopwords]  # Remove stopwords
    return ' '.join(filtered_words)  # Join the words back into a sentence

# long_words_bombo = q5[q5['word_count'] > 6][question].to_list()
# model_df[question] = model_df[question].apply(lambda x: remove_stopwords(x) if str(x) in long_words_bombo else x)

# part 2 beware same variable names
ids = model_df['id']  # Store the 'id' column
responses = model_df[question]  # Extract only the responses
responses = responses.reset_index(drop=True)  # Reset index to 0, 1, 2, ...

similarity_matrix = compute_similarity_matrix(
    responses, jellyfish.jaro_winkler_similarity, threshold
)

# Identify clusters using connected components
n_components, labels = connected_components(csgraph=similarity_matrix, directed=False)

# Group responses and their corresponding IDs based on clusters
clusters = {}
for i, label in enumerate(labels):
    if label not in clusters:
        clusters[label] = {'responses': [], 'ids': []}
    clusters[label]['responses'].append(responses[i])  # Store the response
    clusters[label]['ids'].append(ids.iloc[i])  # Store the corresponding ID

############## for analysis ################

# Output clusters
for cluster_id, group in clusters.items():
    print(f"Group {cluster_id}: Responses: {group['responses']}, IDs: {group['ids']}")

# Convert clusters into a DataFrame
cluster_data = []
for cluster_id, group in clusters.items():
    cluster_data.append({
        'Cluster ID': cluster_id,
        'Responses': ', '.join(group['responses']),  # Combine responses into a single string
        'IDs': ', '.join(map(str, group['ids'])),  # Combine IDs into a single string
        'Number of Responses': len(group['responses'])  # Add count of responses in the cluster
    })

# Create the DataFrame
clusters_df = pd.DataFrame(cluster_data)
clusters_df = clusters_df.sort_values(by='Number of Responses', ascending=False)

# Save the DataFrame to a CSV file
clusters_df.to_csv('BIG_FAT_CLUSTERS.csv', index=False)

df_i=clusters_df
df_i['Label'] = df_i['Responses'].apply(ensure_list).apply(find_median_length_string)

# Iterate through each row in all_res_mapping
for index, row in df_i.iterrows():
    ids = row['IDs']  # Get the list of IDs for this group
    label = row['Label']  # Get the label for this group

    # Iterate through each ID in the list
    for id in ids:
        # Find the row in qq where the 'id' column matches the current ID
        match_index = model_df[model_df['id'] == id].index

        # If a match is found, replace the 'question' column with the label
        if not match_index.empty:
            model_df.loc[match_index, question] = label

model_df = model_df.fillna('none')

# force it tf
q2='Q2: How many ingredients would you expect this food item to contain?'
hmmmmm = ['potato' , '#NAME?' ]
model_df[q2] = model_df[q2].replace(hmmmmm, 'none')


# # Save the updated qq DataFrame to a CSV file (optional)
model_df.to_csv('/content/please_be_done.csv', index=False)
# Out:
#      Cluster ID                                          Responses  \
# 26           26  the avengers, the avengers, the avengers, the ...
# 4             4  none, none, none, none, none, none, none, none...
# 7             7  home alone, home alone, home alone, home alone...
# 16           16  teenage mutant ninja turtles, teenage mutant n...
# 9             9  spiderman, spiderman, spiderman no way home, s...
# ..          ...                                                ...
# 317         317                                             shogun
# 318         318                                      fallen angels
# 336         336                                    east side sushi
# 337         337                             chandni chowk to china
# 338         338                             kikis delivery service
#
#                                                    IDs  Number of Responses  \
# 26   715814, 625326, 728522, 633234, 712093, 840827...                  258
# 4    605771, 714863, 718570, 501416, 148179, 719554...                  153
# 7    644623, 722500, 611097, 600957, 632896, 612131...                   69
# 16   614043, 492744, 616449, 507448, 634328, 722431...                   69
# 9    602526, 601609, 724326, 519548, 634964, 602871...                   64
# ..                                                 ...                  ...
# 317                                             629869                    1
# 318                                             523128                    1
# 336                                             622727                    1
# 337                                             606010                    1
# 338                                             630209                    1
#
#                             Label
# 26                   the avengers
# 4                            none
# 7                      home alone
# 16   teenage mutant ninja turtles
# 9                       spiderman
# ..                            ...
# 317                        shogun
# 318                 fallen angels
# 336               east side sushi
# 337        chandni chowk to china
# 338        kikis delivery service
#
# [339 rows x 5 columns]
# Group 0: Responses: ['cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatball', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatball', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs again shawarmas dont appear in that though but hey its food', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatballs', 'cloudy with a chance of meatball', 'cloudy with a chance of meatball'], IDs: [np.int64(716549), np.int64(505318), np.int64(626792), np.int64(497421), np.int64(607160), np.int64(502610), np.int64(715845), np.int64(714901), np.int64(389109), np.int64(629142), np.int64(634825), np.int64(603476), np.int64(389109), np.int64(605254), np.int64(633520), np.int64(629700), np.int64(630928), np.int64(632299), np.int64(603582), np.int64(204508), np.int64(631221), np.int64(629072), np.int64(630044), np.int64(630972), np.int64(419835), np.int64(632125), np.int64(712252), np.int64(727339), np.int64(494373), np.int64(631436)]
# Group 1: Responses: ['all sort of american young boy movies'], IDs: [np.int64(715742)]
# Group 2: Responses: ['action movie', 'action movie'], IDs: [np.int64(727333), np.int64(727333)]
# Group 3: Responses: ['mamma mia'], IDs: [np.int64(606874)]
# Group 4: Responses: ['none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none'], IDs: [np.int64(605771), np.int64(714863), np.int64(718570), np.int64(501416), np.int64(148179), np.int64(719554), np.int64(632091), np.int64(514199), np.int64(520383), np.int64(605254), np.int64(181851), np.int64(716749), np.int64(601941), np.int64(713585), np.int64(526510), np.int64(455047), np.int64(715742), np.int64(605771), np.int64(609789), np.int64(714863), np.int64(715814), np.int64(405521), np.int64(718570), np.int64(501416), np.int64(148179), np.int64(738409), np.int64(617542), np.int64(719554), np.int64(632091), np.int64(514199), np.int64(389697), np.int64(627252), np.int64(616568), np.int64(719735), np.int64(520383), np.int64(526131), np.int64(500077), np.int64(629878), np.int64(602560), np.int64(605254), np.int64(628990), np.int64(625295), np.int64(835223), np.int64(618150), np.int64(181851), np.int64(716749), np.int64(520861), np.int64(626779), np.int64(713585), np.int64(526510), np.int64(455047), np.int64(605771), np.int64(644623), np.int64(714863), np.int64(718570), np.int64(501416), np.int64(148179), np.int64(719554), np.int64(632091), np.int64(514199), np.int64(520383), np.int64(500077), np.int64(525422), np.int64(631216), np.int64(835223), np.int64(618150), np.int64(181851), np.int64(716749), np.int64(626779), np.int64(713585), np.int64(500470), np.int64(526510), np.int64(455047), np.int64(317214), np.int64(520507), np.int64(518809), np.int64(414734), np.int64(630117), np.int64(630999), np.int64(626789), np.int64(632156), np.int64(741428), np.int64(633024), np.int64(626812), np.int64(621555), np.int64(505458), np.int64(522483), np.int64(630977), np.int64(524766), np.int64(386750), np.int64(517064), np.int64(746750), np.int64(632320), np.int64(634455), np.int64(5978), np.int64(520507), np.int64(518809), np.int64(414734), np.int64(411810), np.int64(211158), np.int64(631600), np.int64(630117), np.int64(714062), np.int64(630999), np.int64(626789), np.int64(616713), np.int64(491374), np.int64(741428), np.int64(633024), np.int64(630948), np.int64(605290), np.int64(632125), np.int64(626812), np.int64(634683), np.int64(602482), np.int64(505458), np.int64(619932), np.int64(631069), np.int64(519976), np.int64(522483), np.int64(630977), np.int64(607073), np.int64(526064), np.int64(627638), np.int64(630929), np.int64(611932), np.int64(630738), np.int64(603182), np.int64(746750), np.int64(618333), np.int64(317214), np.int64(634455), np.int64(520507), np.int64(518809), np.int64(414734), np.int64(211158), np.int64(630999), np.int64(626789), np.int64(632156), np.int64(491374), np.int64(409930), np.int64(632975), np.int64(741428), np.int64(633024), np.int64(626812), np.int64(621555), np.int64(522483), np.int64(630977), np.int64(627638), np.int64(741658), np.int64(630738), np.int64(524766), np.int64(60154 ...
# Group 5: Responses: ['dragon', 'dragon', 'drange'], IDs: [np.int64(606929), np.int64(606929), np.int64(606929)]
# Group 6: Responses: ['rick and morty'], IDs: [np.int64(609789)]
# Group 7: Responses: ['home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone', 'home alone'], IDs: [np.int64(644623), np.int64(722500), np.int64(611097), np.int64(600957), np.int64(632896), np.int64(612131), np.int64(601122), np.int64(631125), np.int64(608704), np.int64(603793), np.int64(605519), np.int64(712766), np.int64(520037), np.int64(716650), np.int64(496858), np.int64(604110), np.int64(625295), np.int64(603415), np.int64(738875), np.int64(721831), np.int64(714893), np.int64(618150), np.int64(629041), np.int64(626779), np.int64(611716), np.int64(625315), np.int64(633224), np.int64(229041), np.int64(409723), np.int64(310438), np.int64(627430), np.int64(603812), np.int64(517096), np.int64(746750), np.int64(629285), np.int64(523710), np.int64(602394), np.int64(87783), np.int64(744484), np.int64(522890), np.int64(634690), np.int64(613209), np.int64(211158), np.int64(605148), np.int64(716142), np.int64(498563), np.int64(626754), np.int64(632051), np.int64(631881), np.int64(601983), np.int64(630006), np.int64(626778), np.int64(632868), np.int64(503957), np.int64(630121), np.int64(739254), np.int64(604826), np.int64(601986), np.int64(631141), np.int64(631069), np.int64(627496), np.int64(401586), np.int64(630378), np.int64(622727), np.int64(741592), np.int64(611932), np.int64(522148), np.int64(523080), np.int64(524890)]
# Group 8: Responses: ['the big lebowski', 'the big sick', 'the big short', 'the big short', 'the big lebowski', 'the big short'], IDs: [np.int64(602805), np.int64(626482), np.int64(295428), np.int64(716650), np.int64(609116), np.int64(313577)]
# Group 9: Responses: ['spiderman', 'spiderman', 'spiderman no way home', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman into the spiderverse', 'spiderman', 'spider man spider verse', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman across the spiderverse', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman', 'spiderman'], IDs: [np.int64(602526), np.int64(601609), np.int64(724326), np.int64(519548), np.int64(634964), np.int64(602871), np.int64(744468), np.int64(719735), np.int64(608062), np.int64(525422), np.int64(604770), np.int64(626757), np.int64(632189), np.int64(630389), np.int64(409940), np.int64(607944), np.int64(626479), np.int64(496344), np.int64(726962), np.int64(630962), np.int64(714430), np.int64(632189), np.int64(714430), np.int64(743488), np.int64(393424), np.int64(411781), np.int64(743623), np.int64(413570), np.int64(522205), np.int64(313577), np.int64(617462), np.int64(632909), np.int64(507382), np.int64(525853), np.int64(723931), np.int64(97339), np.int64(522967), np.int64(631496), np.int64(491374), np.int64(407221), np.int64(627792), np.int64(630070), np.int64(209691), np.int64(410380), np.int64(634650), np.int64(716766), np.int64(408898), np.int64(631014), np.int64(524890), np.int64(634977), np.int64(504548), np.int64(523461), np.int64(631902), np.int64(206744), np.int64(411681), np.int64(518733), np.int64(631142), np.int64(633712), np.int64(630929), np.int64(622787), np.int64(631716), np.int64(495424), np.int64(602845), np.int64(631678)]
# Group 10: Responses: ['goodfellas', 'goodfellas', 'goodfellas'], IDs: [np.int64(389328), np.int64(616457), np.int64(519976)]
# Group 11: Responses: ['a goofy movie the disney movie'], IDs: [np.int64(289931)]
# Group 12: Responses: ['dead silence'], IDs: [np.int64(620148)]
# Group 13: Responses: ['la la land'], IDs: [np.int64(387155)]
# Group 14: Responses: ['harry potter', 'harry poter', 'harry potter', 'harry potter', 'harry potter', 'harry potter', 'harry potter'], IDs: [np.int64(516975), np.int64(624540), np.int64(601609), np.int64(496858), np.int64(634646), np.int64(712054), np.int64(523080)]
# Group 15: Responses: ['transformer', 'transformers', 'transformer', 'transformers', 'transformer', 'transformers'], IDs: [np.int64(630825), np.int64(389328), np.int64(630825), np.int64(632893), np.int64(630823), np.int64(631678)]
# Group 16: Responses: ['teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles the turtles are famous for their love of pizza', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles', 'teenage mutant ninja turtles'], IDs: [np.int64(614043), np.int64(492744), np.int64(616449), np.int64(507448), np.int64(634328), np.int64(722431), np.int64(605207), np.int64(617542), np.int64(520828), np.int64(502722), np.int64(627252), np.int64(603838), np.int64(604897), np.int64(738379), np.int64(622023), np.int64(745297), np.int64(608688), np.int64(629025), np.int64(524441), np.int64(399605), np.int64(395712), np.int64(289440), np.int64(601094), np.int64(633143), np.int64(627169), np.int64(406863), np.int64(517064), np.int64(524485), np.int64(632320), np.int64(628558), np.int64(613776), np.int64(634455), np.int64(638838), np.int64(411253), np.int64(744091), np.int64(631600), np.int64(835124), np.int64(629156), np.int64(625319), np.int64(632684), np.int64(718026), np.int64(522345), np.int64(628744), np.int64(603007), np.int64(629221), np.int64(630948), np.int64(630098), np.int64(525420), np.int64(68949), np.int64(543739), np.int64(385307), np.int64(625818), np.int64(626849), np.int64(494103), np.int64(606857), np.int64(632228), np.int64(603612), np.int64(742226), np.int64(312320), np.int64(407257), np.int64(629263), np.int64(387522), np.int64(624443), np.int64(526064), np.int64(609179), np.int64(627638), np.int64(619892), np.int64(603182), np.int64(628986)]
# Group 17: Responses: ['high school musical 3', 'high school musical'], IDs: [np.int64(521125), np.int64(609257)]
# Group 18: Responses: ['despicable me', 'despicable me'], IDs: [np.int64(627780), np.int64(627220)]
# Group 19: Responses: ['toy story', 'toy story', 'toy story', 'toy story', 'toy story', 'toy story', 'toy story', 'toy story'], IDs: [np.int64(618747), np.int64(612538), np.int64(411810), np.int64(600915), np.int64(629659), np.int64(604991), np.int64(718089), np.int64(628736)]
# Group 20: Responses: ['the godfather', 'the godfather', 'the godfather', 'the godfather', 'the godfather', 'the godfather', 'the godfather', 'the godfather', 'the godfather', 'the godfather', 'the godfather', 'the godfather'], IDs: [np.int64(607815), np.int64(614089), np.int64(626482), np.int64(720045), np.int64(630949), np.int64(747734), np.int64(618700), np.int64(601217), np.int64(520303), np.int64(603130), np.int64(630190), np.int64(631046)]
# Group 21: Responses: ['pizza', 'pizza', 'pizza', 'pizza'], IDs: [np.int64(602657), np.int64(743537), np.int64(602560), np.int64(604062)]
# Group 22: Responses: ['fast furious', 'fast and furious', 'fast furious', 'fast and furious', 'fast and furious', 'fast and furious', 'fast and furious', 'fast and furious', 'fast and furious', 'fast and furious', 'fast and furious', 'fast and furious', 'fast furious tokyo drift', 'fast and furious', 'fast and furious', 'fast and furious', 'fast and furious', 'fast and furious'], IDs: [np.int64(501893), np.int64(616568), np.int64(601609), np.int64(502610), np.int64(626757), np.int64(313562), np.int64(313562), np.int64(66222), np.int64(313562), np.int64(411253), np.int64(411810), np.int64(718026), np.int64(628102), np.int64(609179), np.int64(634430), np.int64(609556), np.int64(631046), np.int64(66222)]
# Group 23: Responses: ['garfield', 'garfield', 'garfield', 'garfield', 'garfield', 'garfield', 'garfield', 'garfield'], IDs: [np.int64(606556), np.int64(714598), np.int64(601950), np.int64(601363), np.int64(712898), np.int64(603388), np.int64(414710), np.int64(66222)]
# Group 24: Responses: ['ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatoullie', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille', 'ratatouille'], IDs: [np.int64(616945), np.int64(632153), np.int64(612096), np.int64(627488), np.int64(631012), np.int64(601848), np.int64(633350), np.int64(603664), np.int64(608318), np.int64(609278), np.int64(604386), np.int64(629844), np.int64(520861), np.int64(500470), np.int64(616945), np.int64(627169), np.int64(723968), np.int64(712670), np.int64(606905), np.int64(525567), np.int64(632431), np.int64(508149), np.int64(633001), np.int64(630250), np.int64(616836), np.int64(604132), np.int64(629807), np.int64(626026), np.int64(629959), np.int64(206487), np.int64(631164), np.int64(634683), np.int64(630416), np.int64(631448), np.int64(388729), np.int64(605537), np.int64(631711), np.int64(609556), np.int64(628547), np.int64(495424), np.int64(741658), np.int64(632117), np.int64(743623), np.int64(630044), np.int64(626026), np.int64(630416), np.int64(631448), np.int64(388729), np.int64(605537), np.int64(632117), np.int64(410165), np.int64(630416), np.int64(519986), np.int64(388729), np.int64(605537), np.int64(632117)]
# Group 25: Responses: ['five nights at freddys', 'five nights at freddys', 'five nights at freddys', 'five nights at freddys', 'five nights at freddys'], IDs: [np.int64(630962), np.int64(408630), np.int64(611188), np.int64(738850), np.int64(628093)]
# Group 26: Responses: ['the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the hangover', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers 1', 'the avengers', 'the avengers', 'the avenger', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the hangover', 'the hangover', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the whale', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avengers', 'the avenger ...
# Group 27: Responses: ['back to the future', 'back to the future 2', 'back to the future', 'back to the future', 'back to the future', 'back to the future', 'back to the future part 2'], IDs: [np.int64(502799), np.int64(500077), np.int64(606821), np.int64(306207), np.int64(634468), np.int64(631531), np.int64(629758)]
# Group 28: Responses: ['godfather', 'godfather', 'godfather'], IDs: [np.int64(605278), np.int64(723968), np.int64(602533)]
# Group 29: Responses: ['mystic pizza', 'mystic pizza', 'mystic pizza'], IDs: [np.int64(388888), np.int64(601693), np.int64(603607)]
# Group 30: Responses: ['futurama'], IDs: [np.int64(405521)]
# Group 31: Responses: ['iron man', 'iron man', 'iron man', 'iron man'], IDs: [np.int64(607410), np.int64(714430), np.int64(628559), np.int64(630823)]
# Group 32: Responses: ['life of pi', 'life if pi'], IDs: [np.int64(715795), np.int64(628990)]
# Group 33: Responses: ['any american movie', 'anime', 'anime', 'anime i guess', 'anime', 'anime', 'anime', 'anime movie'], IDs: [np.int64(602824), np.int64(405521), np.int64(625326), np.int64(604062), np.int64(522890), np.int64(716188), np.int64(604132), np.int64(607073)]
# Group 34: Responses: ['king kong'], IDs: [np.int64(618355)]
# Group 35: Responses: ['grown ups', 'grown ups', 'grown ups'], IDs: [np.int64(612478), np.int64(618333), np.int64(634508)]
# Group 36: Responses: ['deadpool', 'deadpool', 'deadpool', 'deadpool', 'deadpool', 'deadpool', 'deadpool', 'deadpool', 'deadpool', 'deadpool', 'deadpool', 'deadpool', 'deadpool', 'deadpool and wolverine', 'deadpool'], IDs: [np.int64(629710), np.int64(411315), np.int64(627599), np.int64(601945), np.int64(738875), np.int64(634430), np.int64(747734), np.int64(628093), np.int64(602394), np.int64(606150), np.int64(630250), np.int64(630006), np.int64(632868), np.int64(603130), np.int64(622787)]
# Group 37: Responses: ['whiplash'], IDs: [np.int64(603476)]
# Group 38: Responses: ['inside out'], IDs: [np.int64(713423)]
# Group 39: Responses: ['superbad', 'superbad', 'superbad', 'superbad'], IDs: [np.int64(606552), np.int64(413014), np.int64(505318), np.int64(600849)]
# Group 40: Responses: ['stranger things'], IDs: [np.int64(738409)]
# Group 41: Responses: ['air bud'], IDs: [np.int64(627427)]
# Group 42: Responses: ['a quiet place day one 2024', 'a quiet place 2'], IDs: [np.int64(631507), np.int64(631216)]
# Group 43: Responses: ['finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo', 'finding nemo'], IDs: [np.int64(627798), np.int64(289931), np.int64(634328), np.int64(632153), np.int64(408630), np.int64(608704), np.int64(605519), np.int64(520037), np.int64(524441), np.int64(743828), np.int64(720045), np.int64(390823), np.int64(625576), np.int64(524485), np.int64(525853), np.int64(628744), np.int64(630972), np.int64(630948), np.int64(632868), np.int64(603130), np.int64(603612)]
# Group 44: Responses: ['my cousin vinny'], IDs: [np.int64(626493)]
# Group 45: Responses: ['eat pray love', 'eat pray love', 'eat pray love'], IDs: [np.int64(603398), np.int64(498848), np.int64(508156)]
# Group 46: Responses: ['comedy', 'comedy movie', 'comedy'], IDs: [np.int64(389697), np.int64(840827), np.int64(24137)]
# Group 47: Responses: ['star wars', 'star wars', 'star wars', 'star wars', 'star wars', 'star wars', 'star wars'], IDs: [np.int64(612567), np.int64(724326), np.int64(228777), np.int64(630949), np.int64(608554), np.int64(626883), np.int64(712054)]
# Group 48: Responses: ['the dark knight', 'the dark knight'], IDs: [np.int64(519681), np.int64(633541)]
# Group 49: Responses: ['pulp fiction', 'pulp fiction', 'pulp fiction'], IDs: [np.int64(606119), np.int64(627636), np.int64(229211)]
# Group 50: Responses: ['the truman show', 'the truman show'], IDs: [np.int64(603933), np.int64(609789)]
# Group 51: Responses: ['breaking bad', 'breaking bad not a movie', 'breaking bad', 'breaking bad', 'breaking bad', 'breaking bad', 'breaking bad'], IDs: [np.int64(524803), np.int64(717116), np.int64(628077), np.int64(609617), np.int64(606010), np.int64(519570), np.int64(608554)]
# Group 52: Responses: ['interstellar', 'interstellar', 'interstellar', 'interstellar', 'interstellar'], IDs: [np.int64(629712), np.int64(607609), np.int64(298481), np.int64(419835), np.int64(517774)]
# Group 53: Responses: ['rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour 3', 'rush hour', 'rush hour 2', 'rush hour', 'rush hour 2', 'rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour', 'rush hour 2', 'rush hour series', 'rush hour', 'rush hour', 'rush hour'], IDs: [np.int64(627505), np.int64(627539), np.int64(616945), np.int64(502799), np.int64(635627), np.int64(630738), np.int64(854745), np.int64(746466), np.int64(387330), np.int64(606905), np.int64(393424), np.int64(600849), np.int64(631909), np.int64(602533), np.int64(629807), np.int64(629072), np.int64(631181), np.int64(414710), np.int64(523461), np.int64(312640), np.int64(407257), np.int64(629263), np.int64(630378)]
# Group 54: Responses: ['shrek', 'shrek', 'shrek', 'shrek2', 'shrek', 'shrek', 'shrek3', 'shrek'], IDs: [np.int64(526131), np.int64(214145), np.int64(602234), np.int64(214145), np.int64(522877), np.int64(602234), np.int64(214145), np.int64(602234)]
# Group 55: Responses: ['scooby doo'], IDs: [np.int64(607065)]
# Group 56: Responses: ['princess diaries the apology scene'], IDs: [np.int64(601945)]
# Group 57: Responses: ['walle'], IDs: [np.int64(629878)]
# Group 58: Responses: ['spy kids 3d'], IDs: [np.int64(627636)]
# Group 59: Responses: ['squid game', 'squid game', 'squid game', 'squid game'], IDs: [np.int64(295428), np.int64(387155), np.int64(295428), np.int64(629025)]
# Group 60: Responses: ['running man'], IDs: [np.int64(228777)]
# Group 61: Responses: ['recep ivedik 2', 'recep ivedik 2'], IDs: [np.int64(607517), np.int64(607517)]
# Group 62: Responses: ['venom'], IDs: [np.int64(714607)]
# Group 63: Responses: ['moneyball'], IDs: [np.int64(497695)]
# Group 64: Responses: ['hangover or any teen party movies which features a lot of sweet stuff'], IDs: [np.int64(715152)]
# Group 65: Responses: ['coraline'], IDs: [np.int64(629010)]
# Group 66: Responses: ['james bond 007', 'james bond'], IDs: [np.int64(635533), np.int64(714062)]
# Group 67: Responses: ['the goofy movie', 'the lego movie', 'the barbie movie', 'the dora movie', 'the emoji movie'], IDs: [np.int64(629792), np.int64(616634), np.int64(638838), np.int64(518733), np.int64(633520)]
# Group 68: Responses: ['carryon'], IDs: [np.int64(634669)]
# Group 69: Responses: ['set it up', 'set it up'], IDs: [np.int64(835223), np.int64(526497)]
# Group 70: Responses: ['green book', 'green book', 'green book', 'green book'], IDs: [np.int64(712938), np.int64(631198), np.int64(712771), np.int64(712054)]
# Group 71: Responses: ['cars', 'cars', 'cars 2', 'cars 2', 'cars 2', 'cars', 'cars', 'cars 2', 'cars 2', 'cars', 'cars', 'cars 2', 'cars 2', 'cars 2', 'cars 3', 'cars'], IDs: [np.int64(617774), np.int64(614043), np.int64(714598), np.int64(626493), np.int64(612538), np.int64(740568), np.int64(600915), np.int64(628093), np.int64(634468), np.int64(522205), np.int64(632684), np.int64(626778), np.int64(408898), np.int64(604969), np.int64(718089), np.int64(628736)]
# Group 72: Responses: ['relaxing comedy'], IDs: [np.int64(714503)]
# Group 73: Responses: ['zootopia', 'zootopia'], IDs: [np.int64(717921), np.int64(711854)]
# Group 74: Responses: ['mario movie', 'mario movie', 'mario movie'], IDs: [np.int64(743828), np.int64(627539), np.int64(634705)]
# Group 75: Responses: ['30 minutes or less'], IDs: [np.int64(517019)]
# Group 76: Responses: ['21 jump street', '21 jump street', '21 jump street'], IDs: [np.int64(193195), np.int64(631716), np.int64(602482)]
# Group 77: Responses: ['free guy'], IDs: [np.int64(627530)]
# Group 78: Responses: ['soul'], IDs: [np.int64(715806)]
# Group 79: Responses: ['life is beautiful'], IDs: [np.int64(606726)]
# Group 80: Responses: ['the wicked'], IDs: [np.int64(613409)]
# Group 81: Responses: ['harold kumar go to white castle'], IDs: [np.int64(13183)]
# Group 82: Responses: ['lord of the rings', 'lord of the rings'], IDs: [np.int64(630949), np.int64(606552)]
# Group 83: Responses: ['little italy', 'little italy', 'little italy', 'little italy'], IDs: [np.int64(712143), np.int64(740568), np.int64(606150), np.int64(630128)]
# Group 84: Responses: ['everything everywhere all at once', 'everything everywhere all at once'], IDs: [np.int64(712702), np.int64(519681)]
# Group 85: Responses: ['barbie', 'barbie', 'barbie', 'barbie 2021'], IDs: [np.int64(519638), np.int64(627488), np.int64(632975), np.int64(522877)]
# Group 86: Responses: ['hitman'], IDs: [np.int64(627800)]
# Group 87: Responses: ['liquorice pizza'], IDs: [np.int64(625576)]
# Group 88: Responses: ['the dictator', 'the dictator', 'the dictator', 'the dictator', 'the dictator', 'the dictator', 'the dictator', 'the dictator', 'the dictator', 'the dictator', 'the dictator', 'the dictator', 'the dictator', 'the dictator'], IDs: [np.int64(606874), np.int64(524803), np.int64(627505), np.int64(387330), np.int64(524992), np.int64(629700), np.int64(625319), np.int64(718026), np.int64(632051), np.int64(603007), np.int64(630972), np.int64(606857), np.int64(630967), np.int64(632228)]
# Group 89: Responses: ['anjaana anjaani'], IDs: [np.int64(626792)]
# Group 90: Responses: ['hawkeye'], IDs: [np.int64(602526)]
# Group 91: Responses: ['argo'], IDs: [np.int64(497421)]
# Group 92: Responses: ['aladdin', 'alladin', 'aladdin', 'aladdin', 'alladin', 'aladdin', 'aladdin', 'aladdin', 'aladdin', 'aladdin', 'aladdin', 'aladdin', 'aladdin', 'aladdin', 'aladdin idk', 'aladdin', 'aladdin', 'aladdin', 'aladdin'], IDs: [np.int64(289931), np.int64(502610), np.int64(612096), np.int64(609278), np.int64(714607), np.int64(629041), np.int64(715806), np.int64(13183), np.int64(523710), np.int64(712670), np.int64(633520), np.int64(635065), np.int64(616836), np.int64(629072), np.int64(631164), np.int64(630121), np.int64(739254), np.int64(634508), np.int64(609556)]
# Group 93: Responses: ['the invisible guest'], IDs: [np.int64(620148)]
# Group 94: Responses: ['titanic'], IDs: [np.int64(630825)]
# Group 95: Responses: ['1001 nights'], IDs: [np.int64(627780)]
# Group 96: Responses: ['shawarma legend', 'shawarma legend', 'shawarma legend', 'shawarma legend', 'shawarma bowl'], IDs: [np.int64(501893), np.int64(713423), np.int64(601941), np.int64(712143), np.int64(712702)]
# Group 97: Responses: ['dangal', 'dangal', 'dangal', 'dangal'], IDs: [np.int64(606556), np.int64(607160), np.int64(715845), np.int64(716766)]
# Group 98: Responses: ['slumdog millionaire', 'slumdog millionaire'], IDs: [np.int64(502799), np.int64(529289)]
# Group 99: Responses: ['cleopatra'], IDs: [np.int64(605278)]
# Group 100: Responses: ['the kite runner', 'the kite runner', 'the kite runner', 'the intern'], IDs: [np.int64(607410), np.int64(606726), np.int64(525567), np.int64(630823)]
# Group 101: Responses: ['2012'], IDs: [np.int64(715795)]
# Group 102: Responses: ['the boys'], IDs: [np.int64(625326)]
# Group 103: Responses: ['mission impossible', 'mission impossible dead reckoning part one', 'mission impossible', 'mission impossible', 'mission impossible'], IDs: [np.int64(627220), np.int64(601848), np.int64(601737), np.int64(607609), np.int64(711854)]
# Group 104: Responses: ['black hawk down', 'black hawk down'], IDs: [np.int64(602824), np.int64(601950)]
# Group 105: Responses: ['dictator', 'dictator'], IDs: [np.int64(618355), np.int64(718089)]
# Group 106: Responses: ['kungfu panda', 'kung fu panda', 'kung fu panda', 'kung fu panda', 'kung fu panda', 'kung fu panda', 'kung fu panda', 'kung fu panda', 'kung fu panda', 'kung fu panda', 'kung fu panda', 'kung fu panda', 'kung fu panda'], IDs: [np.int64(728522), np.int64(626792), np.int64(631012), np.int64(626482), np.int64(633224), np.int64(229041), np.int64(406863), np.int64(633097), np.int64(517064), np.int64(635627), np.int64(616836), np.int64(600915), np.int64(617379)]
# Group 107: Responses: ['how to lose a guy in 10 days', 'how to lose a guy in 10 days'], IDs: [np.int64(600957), np.int64(631046)]
# Group 108: Responses: ['babylon'], IDs: [np.int64(633234)]
# Group 109: Responses: ['prince of egypt'], IDs: [np.int64(627427)]
# Group 110: Responses: ['borat', 'borat', 'borat', 'borat', 'borat', 'borat', 'borat', 'borat'], IDs: [np.int64(411315), np.int64(606119), np.int64(745297), np.int64(606905), np.int64(617029), np.int64(629221), np.int64(525420), np.int64(630190)]
# Group 111: Responses: ['harold and kumar'], IDs: [np.int64(712093)]
# Group 112: Responses: ['gossip girl'], IDs: [np.int64(627488)]
# Group 113: Responses: ['monty python'], IDs: [np.int64(601363)]
# Group 114: Responses: ['khabi khushi khabi gham'], IDs: [np.int64(631012)]
# Group 115: Responses: ['3 idiots', '3 idiots', '3 idiots'], IDs: [np.int64(408630), np.int64(712938), np.int64(501513)]
# Group 116: Responses: ['dune', 'dune', 'dune', 'dune'], IDs: [np.int64(612567), np.int64(519638), np.int64(625349), np.int64(629869)]
# Group 117: Responses: ['parasite', 'parasite', 'parasite'], IDs: [np.int64(519681), np.int64(608062), np.int64(629712)]
# Group 118: Responses: ['batman the dark knight'], IDs: [np.int64(608062)]
# Group 119: Responses: ['the mummy', 'the mummy', 'the menu'], IDs: [np.int64(605519), np.int64(611188), np.int64(743488)]
# Group 120: Responses: ['taxi driver', 'taxi driver'], IDs: [np.int64(629712), np.int64(633541)]
# Group 121: Responses: ['you dont mess with the zohan', 'you dont mess with the zohan'], IDs: [np.int64(608318), np.int64(628102)]
# Group 122: Responses: ['gladiator', 'gladiator'], IDs: [np.int64(497695), np.int64(635179)]
# Group 123: Responses: ['any bollywood movie'], IDs: [np.int64(715152)]
# Group 124: Responses: ['scott pilgrim vs the world', 'scott pilgrim vs the world', 'scott pilgrim', 'scott pilgrim vs the world'], IDs: [np.int64(603415), np.int64(413014), np.int64(390823), np.int64(617029)]
# Group 125: Responses: ['son of babylon'], IDs: [np.int64(635533)]
# Group 126: Responses: ['bad boys'], IDs: [np.int64(721831)]
# Group 127: Responses: ['the social network', 'the social network'], IDs: [np.int64(617774), np.int64(630967)]
# Group 128: Responses: ['documenary', 'documentary'], IDs: [np.int64(714503), np.int64(742611)]
# Group 129: Responses: ['chef', 'chef', 'chef', 'chef', 'chef'], IDs: [np.int64(607944), np.int64(602845), np.int64(635602), np.int64(619892), np.int64(631109)]
# Group 130: Responses: ['minions', 'minions'], IDs: [np.int64(629844), np.int64(602482)]
# Group 131: Responses: ['jurassic park'], IDs: [np.int64(609257)]
# Group 132: Responses: ['wicked'], IDs: [np.int64(717921)]
# Group 133: Responses: ['arcane'], IDs: [np.int64(627530)]
# Group 134: Responses: ['bahen'], IDs: [np.int64(624540)]
# Group 135: Responses: ['legend of shawama'], IDs: [np.int64(723968)]
# Group 136: Responses: ['forest gump'], IDs: [np.int64(613409)]
# Group 137: Responses: ['john wick', 'john wick', 'john wick 4', 'john wick', 'john wick', 'john wick', 'john wick', 'john wick', 'john wick', 'john wick', 'john wick', 'john wick', 'john wick', 'john wick', 'john wick', 'john wick'], IDs: [np.int64(633224), np.int64(634964), np.int64(601848), np.int64(721831), np.int64(310438), np.int64(523128), np.int64(635179), np.int64(613776), np.int64(632909), np.int64(618700), np.int64(410380), np.int64(385307), np.int64(503957), np.int64(206744), np.int64(611932), np.int64(630128)]
# Group 138: Responses: ['good will hunting'], IDs: [np.int64(603812)]
# Group 139: Responses: ['fight club', 'fight club'], IDs: [np.int64(740568), np.int64(504599)]
# Group 140: Responses: ['drive'], IDs: [np.int64(519638)]
# Group 141: Responses: ['lion king', 'lion king'], IDs: [np.int64(406863), np.int64(631909)]
# Group 142: Responses: ['captain of america', 'captain america'], IDs: [np.int64(726962), np.int64(628986)]
# Group 143: Responses: ['spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away 2001', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirit away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away', 'spirited away'], IDs: [np.int64(716549), np.int64(602526), np.int64(519548), np.int64(713423), np.int64(715845), np.int64(411315), np.int64(631507), np.int64(628559), np.int64(625295), np.int64(603415), np.int64(409940), np.int64(399605), np.int64(712938), np.int64(601094), np.int64(517019), np.int64(611188), np.int64(712702), np.int64(631164), np.int64(517774), np.int64(524480), np.int64(634885), np.int64(526064), np.int64(520090), np.int64(630929)]
# Group 144: Responses: ['japanese movies', 'japanese', 'japanese', 'japanese', 'japanese', 'japanese', 'japanese', 'japanese', 'japanese movies food documentaries', 'japanese movie', 'japanese movie', 'japanese movie', 'japanese movie', 'japanese', 'japanese', 'japanese', 'japanese'], IDs: [np.int64(715742), np.int64(492744), np.int64(524803), np.int64(629878), np.int64(602560), np.int64(715152), np.int64(413014), np.int64(712670), np.int64(742611), np.int64(24137), np.int64(630117), np.int64(206487), np.int64(717411), np.int64(505458), np.int64(312320), np.int64(498213), np.int64(630190)]
# Group 145: Responses: ['cartoon movie', 'cartoons'], IDs: [np.int64(727333), np.int64(498213)]
# Group 146: Responses: ['johnny english', 'johnny english', 'johnny english', 'johnny english'], IDs: [np.int64(606874), np.int64(629710), np.int64(608318), np.int64(631583)]
# Group 147: Responses: ['karate kid', 'karate kid', 'karate kid', 'karate kid ii', 'karate kid', 'karate kid'], IDs: [np.int64(505318), np.int64(745297), np.int64(727410), np.int64(630070), np.int64(632228), np.int64(617310)]
# Group 148: Responses: ['wolverine', 'wolverine', 'wolverine', 'wolverine', 'wolverine', 'wolverine', 'wolverine', 'wolverine'], IDs: [np.int64(602805), np.int64(612131), np.int64(601122), np.int64(712766), np.int64(627169), np.int64(744091), np.int64(97339), np.int64(616634)]
# Group 149: Responses: ['jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sush', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi east side sushi finding nemo', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi', 'jiro dreams of sushi'], IDs: [np.int64(497421), np.int64(618747), np.int64(602657), np.int64(507448), np.int64(715814), np.int64(722500), np.int64(601950), np.int64(602871), np.int64(616568), np.int64(603838), np.int64(719735), np.int64(603933), np.int64(603664), np.int64(738379), np.int64(632189), np.int64(608688), np.int64(604386), np.int64(628990), np.int64(635533), np.int64(630389), np.int64(634669), np.int64(395712), np.int64(603388), np.int64(715806), np.int64(629142), np.int64(744484), np.int64(5978), np.int64(606150), np.int64(613209), np.int64(605452), np.int64(630250), np.int64(631531), np.int64(629156), np.int64(631881), np.int64(630098), np.int64(626771), np.int64(603182)]
# Group 150: Responses: ['kill bill', 'kill bill', 'kill bill', 'kill bill', 'kill bill', 'kill bill', 'kill bill', 'kill bill', 'kill bill', 'kill bill', 'kill bill', 'kill bill', 'kill bill', 'kill bill'], IDs: [np.int64(389328), np.int64(611097), np.int64(607160), np.int64(228777), np.int64(629010), np.int64(193195), np.int64(603812), np.int64(498848), np.int64(87783), np.int64(716142), np.int64(711854), np.int64(624443), np.int64(495424), np.int64(529289)]
# Group 151: Responses: ['your name', 'your name', 'your name 2016', 'your name', 'your name', 'your name', 'your name', 'your name', 'your name', 'your name', 'your name', 'your name', 'your name', 'your name', 'your name', 'your name', 'your name'], IDs: [np.int64(620148), np.int64(607815), np.int64(743537), np.int64(632896), np.int64(612567), np.int64(633350), np.int64(634825), np.int64(632320), np.int64(631198), np.int64(630227), np.int64(625319), np.int64(609116), np.int64(631221), np.int64(209691), np.int64(746466), np.int64(631142), np.int64(741592)]
# Group 152: Responses: ['once upon a time in hollywood'], IDs: [np.int64(387155)]
# Group 153: Responses: ['the lord of the rings the fellowship of the ring'], IDs: [np.int64(516975)]
# Group 154: Responses: ['shark tale', 'shark tale', 'shark tale', 'shark tale'], IDs: [np.int64(521125), np.int64(601693), np.int64(413570), np.int64(631902)]
# Group 155: Responses: ['bullet train', 'bullet train', 'bullet train', 'bullet train', 'bullet train', 'bullet train', 'bullet train'], IDs: [np.int64(627780), np.int64(605207), np.int64(714901), np.int64(496344), np.int64(607609), np.int64(626754), np.int64(494373)]
# Group 156: Responses: ['isle of dogs', 'isle of dogs', 'isle of dogs', 'isle of dogs', 'isle of dogs', 'isle of dogs', 'isle of dogs', 'isle of dogs', 'isle of dogs'], IDs: [np.int64(616449), np.int64(617542), np.int64(520828), np.int64(606119), np.int64(626479), np.int64(628558), np.int64(627792), np.int64(616457), np.int64(633712)]
# Group 157: Responses: ['little forest a japanese film'], IDs: [np.int64(501893)]
# Group 158: Responses: ['doraemon', 'doraemon', 'doraemon'], IDs: [np.int64(606556), np.int64(603793), np.int64(854745)]
# Group 159: Responses: ['naruto', 'naruto'], IDs: [np.int64(724326), np.int64(723931)]
# Group 160: Responses: ['jaws', 'jaws'], IDs: [np.int64(630962), np.int64(631436)]
# Group 161: Responses: ['the end of evangelion'], IDs: [np.int64(605278)]
# Group 162: Responses: ['midnight diner', 'midnight diner', 'midnight dinner'], IDs: [np.int64(388888), np.int64(630044), np.int64(501513)]
# ...
# Group 166: Responses: ['the pacific'], IDs: [np.int64(602824)]
# Group 167: Responses: ['weathering with you', 'weathering with you'], IDs: [np.int64(618355), np.int64(629758)]
# Group 168: Responses: ['eternal sunshine of the spotless mind'], IDs: [np.int64(728522)]
# Group 169: Responses: ['my neighbour totoro', 'my neighbor totoro', 'my neighbor totoro', 'my neighbor totoro'], IDs: [np.int64(612478), np.int64(629041), np.int64(525420), np.int64(68949)]
# Group 170: Responses: ['oldboy', 'oldboy', 'oldboy'], IDs: [np.int64(603476), np.int64(633234), np.int64(617462)]
# Group 171: Responses: ['the proposal', 'the room'], IDs: [np.int64(600957), np.int64(629985)]
# Group 172: Responses: ['rurouni kenshin'], IDs: [np.int64(722431)]
# Group 173: Responses: ['gone girl'], IDs: [np.int64(606552)]
# Group 174: Responses: ['my hero academia'], IDs: [np.int64(738409)]
# Group 175: Responses: ['food wars', 'food wars', 'food wars', 'food wars'], IDs: [np.int64(612096), np.int64(604897), np.int64(617178), np.int64(617178)]
# Group 176: Responses: ['liz and the blue bird'], IDs: [np.int64(627427)]
# Group 177: Responses: ['frozen'], IDs: [np.int64(627798)]
# Group 178: Responses: ['seven samurai'], IDs: [np.int64(712093)]
# Group 179: Responses: ['the boy and the heron', 'the boy and the herron'], IDs: [np.int64(601363), np.int64(519822)]
# Group 180: Responses: ['howls moving castle', 'howls moving castle', 'howls moving castle', 'howls moving castle'], IDs: [np.int64(712898), np.int64(635024), np.int64(742226), np.int64(626883)]
# Group 181: Responses: ['suits'], IDs: [np.int64(603398)]
# Group 182: Responses: ['ghibli movies'], IDs: [np.int64(389697)]
# Group 183: Responses: ['bladerunner', 'bladerunner', 'blade runner'], IDs: [np.int64(744468), np.int64(611716), np.int64(494103)]
# Group 184: Responses: ['a silent voice 2016', 'a silent voice'], IDs: [np.int64(502722), np.int64(743623)]
# Group 185: Responses: ['monsters inc', 'monsters inc', 'monster house', 'monsters inc', 'monsters inc', 'monster inc', 'monster', 'monsters inc', 'monster house', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc', 'monsters inc'], IDs: [np.int64(631125), np.int64(627252), np.int64(627636), np.int64(604110), np.int64(629792), np.int64(389109), np.int64(712143), np.int64(635024), np.int64(632975), np.int64(523710), np.int64(602394), np.int64(633001), np.int64(634690), np.int64(634646), np.int64(605148), np.int64(407221), np.int64(543739), np.int64(631141), np.int64(631069), np.int64(604991), np.int64(411117), np.int64(628547), np.int64(620745), np.int64(635602), np.int64(619892)]
# Group 186: Responses: ['inception', 'inception', 'inception'], IDs: [np.int64(627505), np.int64(517774), np.int64(630198)]
# Group 187: Responses: ['big big wolf'], IDs: [np.int64(526131)]
# Group 188: Responses: ['wolf of wall street', 'wolf of wallstreet'], IDs: [np.int64(601945), np.int64(622023)]
# Group 189: Responses: ['romance movie', 'romantic movies'], IDs: [np.int64(840827), np.int64(413395)]
# Group 190: Responses: ['godzilla', 'godzilla', 'godzilla', 'godzilla', 'godzilla', 'godzilla', 'godzilla'], IDs: [np.int64(604770), np.int64(607286), np.int64(603582), np.int64(632051), np.int64(520303), np.int64(525311), np.int64(411681)]
# Group 191: Responses: ['scary movie 4 2006', 'scary movie'], IDs: [np.int64(627599), np.int64(629285)]
# Group 192: Responses: ['the little mermaid'], IDs: [np.int64(609278)]
# Group 193: Responses: ['lost in translation', 'lost in translation', 'lost in translation', 'lost in translation', 'lost in translation'], IDs: [np.int64(614089), np.int64(289440), np.int64(717116), np.int64(603189), np.int64(621982)]
# Group 194: Responses: ['pirates of the carribeans', 'pirates of the caribbean', 'pirates of the caribbean'], IDs: [np.int64(714607), np.int64(522877), np.int64(629985)]
# Group 195: Responses: ['gran turismo'], IDs: [np.int64(617774)]
# Group 196: Responses: ['short movie because i eat it fast'], IDs: [np.int64(714503)]
# Group 197: Responses: ['the breakfast club', 'the breakfast club', 'the breakfast club', 'the breakfast club'], IDs: [np.int64(714893), np.int64(625315), np.int64(409723), np.int64(629615)]
# Group 198: Responses: ['ponyo', 'ponyo', 'ponyo'], IDs: [np.int64(607944), np.int64(627430), np.int64(747734)]
# Group 199: Responses: ['samurai jack'], IDs: [np.int64(629844)]
# Group 200: Responses: ['mean girls', 'mean girls'], IDs: [np.int64(609257), np.int64(605290)]
# Group 201: Responses: ['girls trip'], IDs: [np.int64(717921)]
# Group 202: Responses: ['passengers2016'], IDs: [np.int64(633143)]
# Group 203: Responses: ['madagascar', 'madagascar', 'madagascar', 'madagascar', 'madagascar 2', 'madagascar', 'madagascar', 'madagascar'], IDs: [np.int64(520861), np.int64(625349), np.int64(519822), np.int64(632299), np.int64(522345), np.int64(634650), np.int64(522477), np.int64(622787)]
# Group 204: Responses: ['koe no katachi'], IDs: [np.int64(627530)]
# Group 205: Responses: ['talented'], IDs: [np.int64(624540)]
# Group 206: Responses: ['crayon shinchan the movie', 'crayon shinchan'], IDs: [np.int64(601941), np.int64(387522)]
# Group 207: Responses: ['memoirs of a geisha', 'memoirs of a geisha', 'memoirs of a geisha', 'memoirs of a geisha', 'memory of a geisha'], IDs: [np.int64(613409), np.int64(13183), np.int64(603607), np.int64(712252), np.int64(712771)]
# Group 208: Responses: ['masterchef', 'masterchef'], IDs: [np.int64(738850), np.int64(523080)]
# Group 209: Responses: ['the last samurai', 'the last samurai', 'the samurai', '7 samurai', 'the last samurai'], IDs: [np.int64(627539), np.int64(522967), np.int64(603007), np.int64(626026), np.int64(631014)]
# Group 210: Responses: ['suzume'], IDs: [np.int64(627800)]
# Group 211: Responses: ['detective conan'], IDs: [np.int64(726962)]
# Group 212: Responses: ['big hero 6', 'big hero 6', 'big hero 6', 'big hero 6', 'big hero 6', 'big hero 6'], IDs: [np.int64(628077), np.int64(638838), np.int64(629700), np.int64(629221), np.int64(419835), np.int64(625818)]
# Group 213: Responses: ['snowpiercer'], IDs: [np.int64(517096)]
# Group 214: Responses: ['yakuza'], IDs: [np.int64(606821)]
# Group 215: Responses: ['wizards of waverly place movie'], IDs: [np.int64(387330)]
# Group 216: Responses: ['saving private ryan'], IDs: [np.int64(519570)]
# Group 217: Responses: ['mr deeds'], IDs: [np.int64(5978)]
# Group 218: Responses: ['murder mystery'], IDs: [np.int64(607286)]
# Group 219: Responses: ['the super mario bros movie'], IDs: [np.int64(630227)]
# Group 220: Responses: ['the ritual'], IDs: [np.int64(630198)]
# Group 221: Responses: ['breakaway'], IDs: [np.int64(635065)]
# Group 222: Responses: ['uncle grandpa'], IDs: [np.int64(605452)]
# Group 223: Responses: ['the grinch', 'the grinch'], IDs: [np.int64(634764), np.int64(629985)]
# Group 224: Responses: ['futurama benders big score'], IDs: [np.int64(631583)]
# Group 225: Responses: ['the italian job', 'the italian job', 'the italian job', 'the italian job', 'the italian job'], IDs: [np.int64(616713), np.int64(716188), np.int64(717411), np.int64(626771), np.int64(617310)]
# Group 226: Responses: ['any kind really probably something more relaxed for leisure'], IDs: [np.int64(409930)]
# Group 227: Responses: ['american pie'], IDs: [np.int64(633097)]
# Group 228: Responses: ['friday'], IDs: [np.int64(629869)]
# Group 229: Responses: ['this is the end'], IDs: [np.int64(523128)]
# Group 230: Responses: ['ready player one there is pacman inside and pizza looks like one'], IDs: [np.int64(745732)]
# Group 231: Responses: ['the gentlemen'], IDs: [np.int64(634566)]
# Group 232: Responses: ['gilmore girls'], IDs: [np.int64(631109)]
# Group 233: Responses: ['happy gilmore'], IDs: [np.int64(628102)]
# Group 234: Responses: ['back in action'], IDs: [np.int64(603189)]
# Group 235: Responses: ['die hard'], IDs: [np.int64(525311)]
# Group 236: Responses: ['neverending story'], IDs: [np.int64(604969)]
# Group 237: Responses: ['maze runner'], IDs: [np.int64(524480)]
# Group 238: Responses: ['diary of a wimpy kid rodrick rules', 'diary of a wimpy kid'], IDs: [np.int64(629615), np.int64(620745)]
# Group 239: Responses: ['malena'], IDs: [np.int64(522477)]
# Group 240: Responses: ['anchorman'], IDs: [np.int64(312640)]
# Group 241: Responses: ['friends', 'friends'], IDs: [np.int64(854745), np.int64(501513)]
# Group 242: Responses: ['terminator'], IDs: [np.int64(296589)]
# Group 243: Responses: ['men in black', 'men in black', 'men in black'], IDs: [np.int64(387820), np.int64(621982), np.int64(629285)]
# Group 244: Responses: ['the davinci code'], IDs: [np.int64(746466)]
# Group 245: Responses: ['crazy stupid love', 'crazy stupid love'], IDs: [np.int64(519986), np.int64(411781)]
# Group 246: Responses: ['the hunger games'], IDs: [np.int64(626883)]
# Group 247: Responses: ['luca', 'lucy'], IDs: [np.int64(634885), np.int64(634683)]
# Group 248: Responses: ['any movie set in new york'], IDs: [np.int64(619932)]
# Group 249: Responses: ['waynes world'], IDs: [np.int64(629723)]
# Group 250: Responses: ['scific type'], IDs: [np.int64(607073)]
# Group 251: Responses: ['do the right thing'], IDs: [np.int64(411117)]
# Group 252: Responses: ['space jam'], IDs: [np.int64(520090)]
# Group 253: Responses: ['spongebob', 'spongebob'], IDs: [np.int64(617379), np.int64(630209)]
# Group 254: Responses: ['step brothers'], IDs: [np.int64(529289)]
# Group 255: Responses: ['horror movie'], IDs: [np.int64(601547)]
# Group 256: Responses: ['the princess diaries'], IDs: [np.int64(617178)]
# Group 257: Responses: ['oppenheimer', 'oppenheimer', 'oppenheimer'], IDs: [np.int64(618333), np.int64(601217), np.int64(629659)]
# Group 258: Responses: ['i think of movies that ive watch with either my friends or my siblings'], IDs: [np.int64(317214)]
# Group 259: Responses: ['pursuit of happyness'], IDs: [np.int64(306207)]
# Group 260: Responses: ['middle east movie', 'middle east movie', 'middle east movie', 'middle eastern movies', 'middle east movie', 'middle east movie', 'middle eastern movie'], IDs: [np.int64(742611), np.int64(24137), np.int64(409930), np.int64(716188), np.int64(498213), np.int64(606010), np.int64(601547)]
# Group 261: Responses: ['drishyam'], IDs: [np.int64(630928)]
# Group 262: Responses: ['us'], IDs: [np.int64(630227)]
# Group 263: Responses: ['nosferatu'], IDs: [np.int64(519822)]
# Group 264: Responses: ['alien'], IDs: [np.int64(525853)]
# Group 265: Responses: ['indiana jones', 'indian movie'], IDs: [np.int64(723931), np.int64(717411)]
# Group 266: Responses: ['angry birds'], IDs: [np.int64(632893)]
# Group 267: Responses: ['the road to fallujah'], IDs: [np.int64(603582)]
# Group 268: Responses: ['kingdom of heaven'], IDs: [np.int64(298481)]
# Group 269: Responses: ['lawrence of arabia', 'lawrence of arabia'], IDs: [np.int64(631583), np.int64(601737)]
# Group 270: Responses: ['time of happiness'], IDs: [np.int64(629758)]
# Group 271: Responses: ['hangover'], IDs: [np.int64(631221)]
# Group 272: Responses: ['coco'], IDs: [np.int64(601983)]
# Group 273: Responses: ['11sep'], IDs: [np.int64(601217)]
# Group 274: Responses: ['13 hours'], IDs: [np.int64(634705)]
# Group 275: Responses: ['murder on the orient express'], IDs: [np.int64(520303)]
# Group 276: Responses: ['three idiots'], IDs: [np.int64(631181)]
# Group 277: Responses: ['shazam'], IDs: [np.int64(745732)]
# Group 278: Responses: ['the lion king'], IDs: [np.int64(634566)]
# Group 279: Responses: ['mulan', 'mulan', 'mulan', 'mulan'], IDs: [np.int64(631109), np.int64(630121), np.int64(634977), np.int64(631448)]
# Group 280: Responses: ['mandoob'], IDs: [np.int64(603189)]
# Group 281: Responses: ['the prince of egypt'], IDs: [np.int64(631014)]
# Group 282: Responses: ['south park the end of obesity'], IDs: [np.int64(296589)]
# Group 283: Responses: ['yeh jawaani hai deewani'], IDs: [np.int64(387820)]
# Group 284: Responses: ['dabba'], IDs: [np.int64(712771)]
# Group 285: Responses: ['cheech chong'], IDs: [np.int64(312320)]
# Group 286: Responses: ['shawshank redemption'], IDs: [np.int64(634885)]
# Group 287: Responses: ['mad max'], IDs: [np.int64(601986)]
# Group 288: Responses: ['taken 2'], IDs: [np.int64(401586)]
# Group 289: Responses: ['ferris buellers day off'], IDs: [np.int64(631678)]
# Group 290: Responses: ['chinese zodiac'], IDs: [np.int64(613484)]
# Group 291: Responses: ['sonic the hedgehog'], IDs: [np.int64(631711)]
# Group 292: Responses: ['bollywood'], IDs: [np.int64(522148)]
# Group 293: Responses: ['burnt'], IDs: [np.int64(386750)]
# Group 294: Responses: ['pokemon', 'pokemon', 'pokemon'], IDs: [np.int64(632431), np.int64(835124), np.int64(522148)]
# Group 295: Responses: ['house md'], IDs: [np.int64(519570)]
# Group 296: Responses: ['the fast and the furious tokyo drift', 'the fast and the furious tokyo drift'], IDs: [np.int64(508149), np.int64(631496)]
# Group 297: Responses: ['who am i jackie chan'], IDs: [np.int64(306207)]
# Group 298: Responses: ['kodoku no gurume', 'kodoku no gurume'], IDs: [np.int64(630928), np.int64(716766)]
# Group 299: Responses: ['gi joe'], IDs: [np.int64(617029)]
# Group 300: Responses: ['penguins of madagascar', 'pengnuins of madagascar', 'penguins of madagascar'], IDs: [np.int64(635065), np.int64(631600), np.int64(631716)]
# Group 301: Responses: ['aquaman', 'aquaman'], IDs: [np.int64(628986), np.int64(613484)]
# Group 302: Responses: ['47 ronin', '47 ronin'], IDs: [np.int64(507382), np.int64(606857)]
# Group 303: Responses: ['9'], IDs: [np.int64(634764)]
# Group 304: Responses: ['wags'], IDs: [np.int64(498563)]
# Group 305: Responses: ['notting hill'], IDs: [np.int64(526497)]
# Group 306: Responses: ['made in abyss dawn of the deep soul'], IDs: [np.int64(625349)]
# Group 307: Responses: ['meitantei konan'], IDs: [np.int64(504599)]
# Group 308: Responses: ['shangchi', 'shanghai noon', 'shang chi'], IDs: [np.int64(632893), np.int64(634566), np.int64(518733)]
# Group 309: Responses: ['billions tv show'], IDs: [np.int64(616713)]
# Group 310: Responses: ['ip man'], IDs: [np.int64(204508)]
# Group 311: Responses: ['django unchained'], IDs: [np.int64(601983)]
# Group 312: Responses: ['shangchi and the legend of the ten rings', 'shang chi the legend of ten rings'], IDs: [np.int64(634705), np.int64(609617)]
# Group 313: Responses: ['casablanca'], IDs: [np.int64(633541)]
# Group 314: Responses: ['pacific rim'], IDs: [np.int64(629959)]
# Group 315: Responses: ['train to busan'], IDs: [np.int64(633097)]
# Group 316: Responses: ['love hard'], IDs: [np.int64(605290)]
# Group 317: Responses: ['shogun'], IDs: [np.int64(629869)]
# Group 318: Responses: ['fallen angels'], IDs: [np.int64(523128)]
# Group 319: Responses: ['totoro', 'totoro'], IDs: [np.int64(727410), np.int64(619932)]
# Group 320: Responses: ['shinchan the movie chounouryoku daikessen tobe tobe temakizushi'], IDs: [np.int64(745732)]
# Group 321: Responses: ['one piece', 'one piece film gold'], IDs: [np.int64(229211), np.int64(386750)]
# Group 322: Responses: ['turning red', 'turning red', 'turning red'], IDs: [np.int64(626849), np.int64(632125), np.int64(631711)]
# Group 323: Responses: ['hunger'], IDs: [np.int64(630967)]
# Group 324: Responses: ['the meg 2018'], IDs: [np.int64(504548)]
# Group 325: Responses: ['ultraman rising'], IDs: [np.int64(739254)]
# Group 326: Responses: ['pearl harbour'], IDs: [np.int64(296589)]
# Group 327: Responses: ['good time'], IDs: [np.int64(604826)]
# Group 328: Responses: ['who am i 2005'], IDs: [np.int64(387820)]
# Group 329: Responses: ['last samurai'], IDs: [np.int64(601737)]
# Group 330: Responses: ['city hunter'], IDs: [np.int64(727339)]
# Group 331: Responses: ['alitathe warrior'], IDs: [np.int64(601986)]
# Group 332: Responses: ['haikyu'], IDs: [np.int64(627496)]
# Group 333: Responses: ['the spy next door'], IDs: [np.int64(401586)]
# Group 334: Responses: ['breakfast club'], IDs: [np.int64(519976)]
# Group 335: Responses: ['heretic'], IDs: [np.int64(629723)]
# Group 336: Responses: ['east side sushi'], IDs: [np.int64(622727)]
# Group 337: Responses: ['chandni chowk to china'], IDs: [np.int64(606010)]
# Group 338: Responses: ['kikis delivery service'], IDs: [np.int64(630209)]
